# %% [markdown]
# # Proyek Analisis Data: Air Quality Dataset
# - **Nama:** Muhammad Dani Nasution
# - **Email:** mdaninas@gmail.com
# - **ID Dicoding:** mdaninas19

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Saat salah satu dari PM2.5 meningkat apakah PM10 meningkat juga?
# - Apakah curah hujan memiliki peran dalam turunnya polusi di udara

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# Read csv `Aothizhongxin`

# %%
aothizhongxin_dframe = pd.read_csv("./data/PRSA_Data_Aotizhongxin_20130301-20170228.csv")
aothizhongxin_dframe
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0
# 1          2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0
# 2          3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0
# 3          4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0
# 4          5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 35059  35060  2017      2   28    19   12.0  29.0   5.0  35.0  400.0  95.0
# 35060  35061  2017      2   28    20   13.0  37.0   7.0  45.0  500.0  81.0
# 35061  35062  2017      2   28    21   16.0  37.0  10.0  66.0  700.0  58.0
# 35062  35063  2017      2   28    22   21.0  44.0  12.0  87.0  700.0  35.0
# 35063  35064  2017      2   28    23   19.0  31.0  10.0  79.0  600.0  42.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# 0      -0.7  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1      -1.1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2      -1.1  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3      -1.4  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4      -2.0  1025.2 -19.5   0.0    N   2.0  Aotizhongxin
# ...     ...     ...   ...   ...  ...   ...           ...
# 35059  12.5  1013.5 -16.2   0.0   NW   2.4  Aotizhongxin
# 35060  11.6  1013.6 -15.1   0.0  WNW   0.9  Aotizhongxin
# 35061  10.8  1014.2 -13.3   0.0   NW   1.1  Aotizhongxin
# 35062  10.5  1014.4 -12.9   0.0  NNW   1.2  Aotizhongxin
# 35063   8.6  1014.1 -15.9   0.0  NNE   1.3  Aotizhongxin
#
# [35064 rows x 18 columns]

# %% [markdown]
# Read csv `Changping`

# %%
changping_dframe = pd.read_csv("./data/PRSA_Data_Changping_20130301-20170228.csv")
changping_dframe
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0
# 1          2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0
# 2          3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0
# 3          4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0
# 4          5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 35059  35060  2017      2   28    19   28.0  47.0   4.0  14.0  300.0   NaN
# 35060  35061  2017      2   28    20   12.0  12.0   3.0  23.0  500.0  64.0
# 35061  35062  2017      2   28    21    7.0  23.0   5.0  17.0  500.0  68.0
# 35062  35063  2017      2   28    22   11.0  20.0   3.0  15.0  500.0  72.0
# 35063  35064  2017      2   28    23   20.0  25.0   6.0  28.0  900.0  54.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM    station
# 0      -2.3  1020.8 -19.7   0.0    E   0.5  Changping
# 1      -2.5  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2      -3.0  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3      -3.6  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4      -3.5  1022.3 -19.4   0.0    N   2.1  Changping
# ...     ...     ...   ...   ...  ...   ...        ...
# 35059  11.7  1008.9 -13.3   0.0  NNE   1.3  Changping
# 35060  10.9  1009.0 -14.0   0.0    N   2.1  Changping
# 35061   9.5  1009.4 -13.0   0.0    N   1.5  Changping
# 35062   7.8  1009.6 -12.6   0.0   NW   1.4  Changping
# 35063   7.0  1009.4 -12.2   0.0    N   1.9  Changping
#
# [35064 rows x 18 columns]

# %% [markdown]
# Read csv `Dingling`

# %%
dingling_dframe = pd.read_csv("./data/PRSA_Data_Dingling_20130301-20170228.csv")
dingling_dframe
# Out:
#           No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO     O3  \
# 0          1  2013      3    1     0    4.0   4.0  3.0  NaN  200.0   82.0
# 1          2  2013      3    1     1    7.0   7.0  3.0  NaN  200.0   80.0
# 2          3  2013      3    1     2    5.0   5.0  3.0  2.0  200.0   79.0
# 3          4  2013      3    1     3    6.0   6.0  3.0  NaN  200.0   79.0
# 4          5  2013      3    1     4    5.0   5.0  3.0  NaN  200.0   81.0
# ...      ...   ...    ...  ...   ...    ...   ...  ...  ...    ...    ...
# 35059  35060  2017      2   28    19   11.0  11.0  2.0  2.0  200.0   99.0
# 35060  35061  2017      2   28    20   13.0  13.0  2.0  2.0  200.0  101.0
# 35061  35062  2017      2   28    21    9.0  14.0  2.0  2.0  200.0  102.0
# 35062  35063  2017      2   28    22   10.0  12.0  2.0  2.0  200.0   97.0
# 35063  35064  2017      2   28    23   13.0  16.0  4.0  9.0  500.0   74.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM   station
# 0      -2.3  1020.8 -19.7   0.0    E   0.5  Dingling
# 1      -2.5  1021.3 -19.0   0.0  ENE   0.7  Dingling
# 2      -3.0  1021.3 -19.9   0.0  ENE   0.2  Dingling
# 3      -3.6  1021.8 -19.1   0.0  NNE   1.0  Dingling
# 4      -3.5  1022.3 -19.4   0.0    N   2.1  Dingling
# ...     ...     ...   ...   ...  ...   ...       ...
# 35059  11.7  1008.9 -13.3   0.0  NNE   1.3  Dingling
# 35060  10.9  1009.0 -14.0   0.0    N   2.1  Dingling
# 35061   9.5  1009.4 -13.0   0.0    N   1.5  Dingling
# 35062   7.8  1009.6 -12.6   0.0   NW   1.4  Dingling
# 35063   7.0  1009.4 -12.2   0.0    N   1.9  Dingling
#
# [35064 rows x 18 columns]

# %% [markdown]
# Read csv `Dongsi`

# %%
dongsi_dframe = pd.read_csv("./data/PRSA_Data_Dongsi_20130301-20170228.csv")
dongsi_dframe
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2      CO    O3  \
# 0          1  2013      3    1     0    9.0   9.0   3.0  17.0   300.0  89.0
# 1          2  2013      3    1     1    4.0   4.0   3.0  16.0   300.0  88.0
# 2          3  2013      3    1     2    7.0   7.0   NaN  17.0   300.0  60.0
# 3          4  2013      3    1     3    3.0   3.0   5.0  18.0     NaN   NaN
# 4          5  2013      3    1     4    3.0   3.0   7.0   NaN   200.0  84.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...     ...   ...
# 35059  35060  2017      2   28    19   16.0  51.0   3.0  29.0   400.0  73.0
# 35060  35061  2017      2   28    20   18.0  45.0   3.0  43.0   500.0  54.0
# 35061  35062  2017      2   28    21   23.0  58.0   5.0  61.0   700.0  28.0
# 35062  35063  2017      2   28    22   23.0  53.0   9.0  75.0   900.0  15.0
# 35063  35064  2017      2   28    23   30.0  71.0  11.0  87.0  1200.0   4.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM station
# 0      -0.5  1024.5 -21.4   0.0  NNW   5.7  Dongsi
# 1      -0.7  1025.1 -22.1   0.0   NW   3.9  Dongsi
# 2      -1.2  1025.3 -24.6   0.0  NNW   5.3  Dongsi
# 3      -1.4  1026.2 -25.5   0.0    N   4.9  Dongsi
# 4      -1.9  1027.1 -24.5   0.0  NNW   3.2  Dongsi
# ...     ...     ...   ...   ...  ...   ...     ...
# 35059  12.5  1013.5 -16.2   0.0   NW   2.4  Dongsi
# 35060  11.6  1013.6 -15.1   0.0  WNW   0.9  Dongsi
# 35061  10.8  1014.2 -13.3   0.0   NW   1.1  Dongsi
# 35062  10.5  1014.4 -12.9   0.0  NNW   1.2  Dongsi
# 35063   8.6  1014.1 -15.9   0.0  NNE   1.3  Dongsi
#
# [35064 rows x 18 columns]

# %% [markdown]
# Read csv `Guanyuan`

# %%
guanyuan_dframe = pd.read_csv("./data/PRSA_Data_Guanyuan_20130301-20170228.csv")
guanyuan_dframe
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    4.0   4.0  14.0  20.0  300.0  69.0
# 1          2  2013      3    1     1    4.0   4.0  13.0  17.0  300.0  72.0
# 2          3  2013      3    1     2    3.0   3.0  10.0  19.0  300.0  69.0
# 3          4  2013      3    1     3    3.0   6.0   7.0  24.0  400.0  62.0
# 4          5  2013      3    1     4    3.0   6.0   5.0  14.0  400.0  71.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 35059  35060  2017      2   28    19   13.0  37.0   3.0  36.0  400.0  60.0
# 35060  35061  2017      2   28    20   20.0  43.0   4.0  48.0  500.0  43.0
# 35061  35062  2017      2   28    21   16.0  33.0   5.0  39.0  500.0  50.0
# 35062  35063  2017      2   28    22   11.0  24.0   5.0  47.0  500.0  41.0
# 35063  35064  2017      2   28    23   15.0  27.0   5.0  53.0  600.0  33.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM   station
# 0      -0.7  1023.0 -18.8   0.0  NNW   4.4  Guanyuan
# 1      -1.1  1023.2 -18.2   0.0    N   4.7  Guanyuan
# 2      -1.1  1023.5 -18.2   0.0  NNW   5.6  Guanyuan
# 3      -1.4  1024.5 -19.4   0.0   NW   3.1  Guanyuan
# 4      -2.0  1025.2 -19.5   0.0    N   2.0  Guanyuan
# ...     ...     ...   ...   ...  ...   ...       ...
# 35059  12.5  1013.5 -16.2   0.0   NW   2.4  Guanyuan
# 35060  11.6  1013.6 -15.1   0.0  WNW   0.9  Guanyuan
# 35061  10.8  1014.2 -13.3   0.0   NW   1.1  Guanyuan
# 35062  10.5  1014.4 -12.9   0.0  NNW   1.2  Guanyuan
# 35063   8.6  1014.1 -15.9   0.0  NNE   1.3  Guanyuan
#
# [35064 rows x 18 columns]

# %% [markdown]
# Read csv `Gucheng`

# %%
gucheng_dframe = pd.read_csv("./data/PRSA_Data_Gucheng_20130301-20170228.csv")
gucheng_dframe
# Out:
#           No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    6.0  18.0  5.0   NaN  800.0  88.0
# 1          2  2013      3    1     1    6.0  15.0  5.0   NaN  800.0  88.0
# 2          3  2013      3    1     2    5.0  18.0  NaN   NaN  700.0  52.0
# 3          4  2013      3    1     3    6.0  20.0  6.0   NaN    NaN   NaN
# 4          5  2013      3    1     4    5.0  17.0  5.0   NaN  600.0  73.0
# ...      ...   ...    ...  ...   ...    ...   ...  ...   ...    ...   ...
# 35059  35060  2017      2   28    19   14.0  58.0  4.0  19.0  500.0  56.0
# 35060  35061  2017      2   28    20   27.0  83.0  6.0  60.0  700.0  26.0
# 35061  35062  2017      2   28    21   22.0  37.0  7.0  52.0  600.0  27.0
# 35062  35063  2017      2   28    22    9.0  23.0  3.0  13.0  400.0  57.0
# 35063  35064  2017      2   28    23   12.0  48.0  5.0  48.0  600.0  28.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM  station
# 0       0.1  1021.1 -18.6   0.0   NW   4.4  Gucheng
# 1      -0.3  1021.5 -19.0   0.0   NW   4.0  Gucheng
# 2      -0.7  1021.5 -19.8   0.0  WNW   4.6  Gucheng
# 3      -1.0  1022.7 -21.2   0.0    W   2.8  Gucheng
# 4      -1.3  1023.0 -21.4   0.0  WNW   3.6  Gucheng
# ...     ...     ...   ...   ...  ...   ...      ...
# 35059  12.8  1009.9 -17.0   0.0  NNW   3.1  Gucheng
# 35060  11.1  1010.4 -15.5   0.0   NW   1.9  Gucheng
# 35061  10.5  1010.8 -15.9   0.0    N   2.3  Gucheng
# 35062   8.9  1010.9 -14.9   0.0   NE   1.6  Gucheng
# 35063   6.2  1010.5 -13.4   0.0  NNE   0.7  Gucheng
#
# [35064 rows x 18 columns]

# %% [markdown]
# Read csv `Huairou`

# %%
huairou_dframe = pd.read_csv("./data/PRSA_Data_Huairou_20130301-20170228.csv")
huairou_dframe
# Out:
#           No  year  month  day  hour  PM2.5  PM10  SO2   NO2      CO    O3  \
# 0          1  2013      3    1     0    7.0   7.0  3.0   2.0   100.0  91.0
# 1          2  2013      3    1     1    4.0   4.0  3.0   NaN   100.0  92.0
# 2          3  2013      3    1     2    4.0   4.0  NaN   NaN   100.0  91.0
# 3          4  2013      3    1     3    3.0   3.0  3.0   2.0     NaN   NaN
# 4          5  2013      3    1     4    3.0   3.0  7.0   NaN   300.0  86.0
# ...      ...   ...    ...  ...   ...    ...   ...  ...   ...     ...   ...
# 35059  35060  2017      2   28    19   16.0  28.0  2.0  19.0   300.0  95.0
# 35060  35061  2017      2   28    20   21.0  34.0  4.0  24.0   500.0  80.0
# 35061  35062  2017      2   28    21   17.0  33.0  2.0  39.0   900.0  60.0
# 35062  35063  2017      2   28    22   11.0  29.0  3.0  32.0  1400.0  69.0
# 35063  35064  2017      2   28    23   11.0  20.0  2.0  27.0   400.0  77.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM  station
# 0      -2.3  1020.3 -20.7   0.0  WNW   3.1  Huairou
# 1      -2.7  1020.8 -20.5   0.0  NNW   1.5  Huairou
# 2      -3.2  1020.6 -21.4   0.0   NW   1.8  Huairou
# 3      -3.3  1021.3 -23.7   0.0  NNW   2.4  Huairou
# 4      -4.1  1022.1 -22.7   0.0  NNW   2.2  Huairou
# ...     ...     ...   ...   ...  ...   ...      ...
# 35059   9.9  1008.6 -14.1   0.0  WNW   1.8  Huairou
# 35060   9.5  1008.9 -14.4   0.0  SSW   1.3  Huairou
# 35061   8.4  1009.3 -14.6   0.0   SE   1.5  Huairou
# 35062   8.3  1009.5 -14.7   0.0  ENE   3.2  Huairou
# 35063   6.7  1009.3 -13.6   0.0   NE   1.9  Huairou
#
# [35064 rows x 18 columns]

# %% [markdown]
# Read csv `Nongzhanguan`

# %%
nongzhanguan_dframe = pd.read_csv("./data/PRSA_Data_Nongzhanguan_20130301-20170228.csv")
nongzhanguan_dframe
# Out:
#           No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    5.0  14.0  4.0  12.0  200.0  85.0
# 1          2  2013      3    1     1    8.0  12.0  6.0  14.0  200.0  84.0
# 2          3  2013      3    1     2    3.0   6.0  5.0  14.0  200.0  83.0
# 3          4  2013      3    1     3    5.0   5.0  5.0  14.0  200.0  84.0
# 4          5  2013      3    1     4    5.0   5.0  6.0  21.0  200.0  77.0
# ...      ...   ...    ...  ...   ...    ...   ...  ...   ...    ...   ...
# 35059  35060  2017      2   28    19   14.0  21.0  3.0  27.0  400.0  72.0
# 35060  35061  2017      2   28    20   18.0  27.0  3.0  37.0  400.0  59.0
# 35061  35062  2017      2   28    21   15.0  39.0  5.0  50.0  600.0  41.0
# 35062  35063  2017      2   28    22   11.0  35.0  6.0  49.0  500.0  41.0
# 35063  35064  2017      2   28    23   10.0  28.0  7.0  48.0  600.0  39.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# 0      -0.5  1024.5 -21.4   0.0  NNW   5.7  Nongzhanguan
# 1      -0.7  1025.1 -22.1   0.0   NW   3.9  Nongzhanguan
# 2      -1.2  1025.3 -24.6   0.0  NNW   5.3  Nongzhanguan
# 3      -1.4  1026.2 -25.5   0.0    N   4.9  Nongzhanguan
# 4      -1.9  1027.1 -24.5   0.0  NNW   3.2  Nongzhanguan
# ...     ...     ...   ...   ...  ...   ...           ...
# 35059  12.5  1013.5 -16.2   0.0   NW   2.4  Nongzhanguan
# 35060  11.6  1013.6 -15.1   0.0  WNW   0.9  Nongzhanguan
# 35061  10.8  1014.2 -13.3   0.0   NW   1.1  Nongzhanguan
# 35062  10.5  1014.4 -12.9   0.0  NNW   1.2  Nongzhanguan
# 35063   8.6  1014.1 -15.9   0.0  NNE   1.3  Nongzhanguan
#
# [35064 rows x 18 columns]

# %% [markdown]
# Read csv `Shunyi`

# %%
shunyi_dframe = pd.read_csv("./data/PRSA_Data_Shunyi_20130301-20170228.csv")
shunyi_dframe
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2      CO    O3  \
# 0          1  2013      3    1     0    3.0   6.0   3.0   8.0   300.0  44.0
# 1          2  2013      3    1     1   12.0  12.0   3.0   7.0   300.0  47.0
# 2          3  2013      3    1     2   14.0  14.0   NaN   7.0   200.0  22.0
# 3          4  2013      3    1     3   12.0  12.0   3.0   5.0     NaN   NaN
# 4          5  2013      3    1     4   12.0  12.0   3.0   NaN   200.0  11.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...     ...   ...
# 35059  35060  2017      2   28    19   27.0  72.0   8.0  92.0   800.0  16.0
# 35060  35061  2017      2   28    20   47.0  55.0  17.0  86.0  1100.0  19.0
# 35061  35062  2017      2   28    21   18.0  28.0   4.0  30.0   500.0  64.0
# 35062  35063  2017      2   28    22   18.0  20.0   9.0  33.0   500.0  59.0
# 35063  35064  2017      2   28    23   15.0  22.0  13.0  34.0   500.0  60.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM station
# 0      -0.9  1025.8 -20.5   0.0   NW   9.3  Shunyi
# 1      -1.1  1026.1 -21.3   0.0   NW   9.4  Shunyi
# 2      -1.7  1026.2 -23.0   0.0   NW   8.6  Shunyi
# 3      -2.1  1027.3 -23.3   0.0   NW   6.6  Shunyi
# 4      -2.4  1027.7 -22.9   0.0   NW   4.5  Shunyi
# ...     ...     ...   ...   ...  ...   ...     ...
# 35059  10.3  1014.2 -12.4   0.0    W   1.8  Shunyi
# 35060   9.8  1014.5  -9.9   0.0   NW   1.5  Shunyi
# 35061   9.1  1014.6 -12.7   0.0   NE   1.7  Shunyi
# 35062   7.1  1015.2 -13.2   0.0  WNW   1.8  Shunyi
# 35063   7.4  1014.9 -11.9   0.0    N   1.4  Shunyi
#
# [35064 rows x 18 columns]

# %% [markdown]
# Read csv `Tiantan`

# %%
tiantan_dframe = pd.read_csv("./data/PRSA_Data_Tiantan_20130301-20170228.csv")
tiantan_dframe
# Out:
#           No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    6.0   6.0  4.0   8.0  300.0  81.0
# 1          2  2013      3    1     1    6.0  29.0  5.0   9.0  300.0  80.0
# 2          3  2013      3    1     2    6.0   6.0  4.0  12.0  300.0  75.0
# 3          4  2013      3    1     3    6.0   6.0  4.0  12.0  300.0  74.0
# 4          5  2013      3    1     4    5.0   5.0  7.0  15.0  400.0  70.0
# ...      ...   ...    ...  ...   ...    ...   ...  ...   ...    ...   ...
# 35059  35060  2017      2   28    19   20.0  48.0  2.0   NaN  500.0   NaN
# 35060  35061  2017      2   28    20   11.0  34.0  3.0  36.0  500.0   NaN
# 35061  35062  2017      2   28    21   18.0  32.0  4.0  48.0  500.0  48.0
# 35062  35063  2017      2   28    22   15.0  42.0  5.0  52.0  600.0  44.0
# 35063  35064  2017      2   28    23   15.0  50.0  5.0  68.0  700.0  21.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM  station
# 0      -0.5  1024.5 -21.4   0.0  NNW   5.7  Tiantan
# 1      -0.7  1025.1 -22.1   0.0   NW   3.9  Tiantan
# 2      -1.2  1025.3 -24.6   0.0  NNW   5.3  Tiantan
# 3      -1.4  1026.2 -25.5   0.0    N   4.9  Tiantan
# 4      -1.9  1027.1 -24.5   0.0  NNW   3.2  Tiantan
# ...     ...     ...   ...   ...  ...   ...      ...
# 35059  12.5  1013.5 -16.2   0.0   NW   2.4  Tiantan
# 35060  11.6  1013.6 -15.1   0.0  WNW   0.9  Tiantan
# 35061  10.8  1014.2 -13.3   0.0   NW   1.1  Tiantan
# 35062  10.5  1014.4 -12.9   0.0  NNW   1.2  Tiantan
# 35063   8.6  1014.1 -15.9   0.0  NNE   1.3  Tiantan
#
# [35064 rows x 18 columns]

# %% [markdown]
# Read csv `Wanliu`

# %%
wanliu_dframe = pd.read_csv("./data/PRSA_Data_Wanliu_20130301-20170228.csv")
wanliu_dframe
# Out:
#           No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    8.0   8.0  6.0  28.0  400.0  52.0
# 1          2  2013      3    1     1    9.0   9.0  6.0  28.0  400.0  50.0
# 2          3  2013      3    1     2    3.0   6.0  NaN  19.0  400.0  55.0
# 3          4  2013      3    1     3   11.0  30.0  8.0  14.0    NaN   NaN
# 4          5  2013      3    1     4    3.0  13.0  9.0   NaN  300.0  54.0
# ...      ...   ...    ...  ...   ...    ...   ...  ...   ...    ...   ...
# 35059  35060  2017      2   28    19   11.0  27.0  4.0  20.0  300.0  81.0
# 35060  35061  2017      2   28    20   15.0  43.0  6.0  55.0  500.0  45.0
# 35061  35062  2017      2   28    21   13.0  35.0  7.0  48.0  500.0  48.0
# 35062  35063  2017      2   28    22   12.0  31.0  5.0  47.0  500.0  50.0
# 35063  35064  2017      2   28    23    7.0  25.0  6.0  86.0  700.0  11.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM station
# 0      -0.7  1023.0 -18.8   0.0  NNW   4.4  Wanliu
# 1      -1.1  1023.2 -18.2   0.0    N   4.7  Wanliu
# 2      -1.1  1023.5 -18.2   0.0  NNW   5.6  Wanliu
# 3      -1.4  1024.5 -19.4   0.0   NW   3.1  Wanliu
# 4      -2.0  1025.2 -19.5   0.0    N   2.0  Wanliu
# ...     ...     ...   ...   ...  ...   ...     ...
# 35059  12.6  1011.9 -14.3   0.0    N   2.0  Wanliu
# 35060   9.4  1012.3 -11.9   0.0  WSW   1.0  Wanliu
# 35061   8.7  1012.8 -13.7   0.0    N   1.1  Wanliu
# 35062   7.8  1012.9 -12.6   0.0  NNE   1.0  Wanliu
# 35063   7.0  1012.6 -11.2   0.0   NE   1.1  Wanliu
#
# [35064 rows x 18 columns]

# %% [markdown]
# Read csv `Wanshouxigong`

# %%
wanshouxigong_dframe = pd.read_csv("./data/PRSA_Data_Wanshouxigong_20130301-20170228.csv")
wanshouxigong_dframe
# Out:
#           No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    9.0   9.0  6.0  17.0  200.0  62.0
# 1          2  2013      3    1     1   11.0  11.0  7.0  14.0  200.0  66.0
# 2          3  2013      3    1     2    8.0   8.0  NaN  16.0  200.0  59.0
# 3          4  2013      3    1     3    8.0   8.0  3.0  16.0    NaN   NaN
# 4          5  2013      3    1     4    8.0   8.0  3.0   NaN  300.0  36.0
# ...      ...   ...    ...  ...   ...    ...   ...  ...   ...    ...   ...
# 35059  35060  2017      2   28    19   11.0  32.0  3.0  24.0  400.0  72.0
# 35060  35061  2017      2   28    20   13.0  32.0  3.0  41.0  500.0  50.0
# 35061  35062  2017      2   28    21   14.0  28.0  4.0  38.0  500.0  54.0
# 35062  35063  2017      2   28    22   12.0  23.0  4.0  30.0  400.0  59.0
# 35063  35064  2017      2   28    23   13.0  19.0  4.0  38.0  600.0  49.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM        station
# 0       0.3  1021.9 -19.0   0.0  WNW   2.0  Wanshouxigong
# 1      -0.1  1022.4 -19.3   0.0  WNW   4.4  Wanshouxigong
# 2      -0.6  1022.6 -19.7   0.0  WNW   4.7  Wanshouxigong
# 3      -0.7  1023.5 -20.9   0.0   NW   2.6  Wanshouxigong
# 4      -0.9  1024.1 -21.7   0.0  WNW   2.5  Wanshouxigong
# ...     ...     ...   ...   ...  ...   ...            ...
# 35059  12.5  1013.5 -16.2   0.0   NW   2.4  Wanshouxigong
# 35060  11.6  1013.6 -15.1   0.0  WNW   0.9  Wanshouxigong
# 35061  10.8  1014.2 -13.3   0.0   NW   1.1  Wanshouxigong
# 35062  10.5  1014.4 -12.9   0.0  NNW   1.2  Wanshouxigong
# 35063   8.6  1014.1 -15.9   0.0  NNE   1.3  Wanshouxigong
#
# [35064 rows x 18 columns]

# %% [markdown]
# **Insight:**
# - Memahami bahwa dataframe yang akan kita analisis adalah terkait kualitas udara,temperature,curah hujan di stasiun stasiun negara china
# - Dataframe memuat terkait data historis kualitas udara,temperatur,curah hujan kota-kota dari tahun 2013 hingga 2017

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# Menilai Dataframe `aotizhongxin_df`

# %%
aothizhongxin_dframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34139 non-null  float64
#  6   PM10     34346 non-null  float64
#  7   SO2      34129 non-null  float64
#  8   NO2      34041 non-null  float64
#  9   CO       33288 non-null  float64
#  10  O3       33345 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %% [markdown]
# Ternyata terdapat nilai yang missing di `aothizhongxin_dframe`

# %% [markdown]
# Mencek fitur yang  datanya missing

# %%
aothizhongxin_dframe.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       925
# PM10        718
# SO2         935
# NO2        1023
# CO         1776
# O3         1719
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %% [markdown]
# Fitur `aothizhongxin_dframe` yang terdapat missing values :
#
#     - PM2.5
#     - PM10
#     - SO2
#     - NO2
#     - CO
#     - O3
#     - TEMP
#     - PRES
#     - DEWP
#     - RAIN
#     - wd
#     - WSPM

# %% [markdown]
# Sekarang kita cek duplikasi data di `aothizhongxin_dframe`

# %%
print("Jumlah duplikasi data :", aothizhongxin_dframe.duplicated().sum())
# Out:
# Jumlah duplikasi data : 0

# %% [markdown]
# Melihat Parameter Statistik

# %%
aothizhongxin_dframe.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34139.000000  34346.000000  34129.000000  34041.000000  33288.000000
# mean      82.773611    110.060391     17.375901     59.305833   1262.945145
# std       82.135694     95.223005     22.823017     37.116200   1221.436236
# min        3.000000      2.000000      0.285600      2.000000    100.000000
# 25%       22.000000     38.000000      3.000000     30.000000    500.000000
# 50%       58.000000     87.000000      9.000000     53.000000    900.000000
# 75%      114.000000    155.000000     21.000000     82.000000   1500.000000
# max      898.000000    984.000000    341.000000    290.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  33345.000000  35044.000000  35044.000000  35044.000000  35044.000000
# mean      56.353358     13.584607   1011.846920      3.123062      0.067421
# std       57.916327     11.399097     10.404047     13.688896      0.910056
# min        0.214200    -16.800000    985.900000    -35.300000      0.000000
# 25%        8.000000      3.100000   1003.300000     -8.100000      0.000000
# 50%       42.000000     14.500000   1011.400000      3.800000      0.000000
# 75%       82.000000     23.300000   1020.100000     15.600000      0.000000
# max      423.000000     40.500000   1042.000000     28.500000     72.500000
#
#                WSPM
# count  35050.000000
# mean       1.708496
# std        1.204071
# min        0.000000
# 25%        0.900000
# 50%        1.400000
# 75%        2.200000
# max       11.200000

# %% [markdown]
# Menilai Dataframe `changping_dframe`

# %%
changping_dframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34290 non-null  float64
#  6   PM10     34482 non-null  float64
#  7   SO2      34436 non-null  float64
#  8   NO2      34397 non-null  float64
#  9   CO       33543 non-null  float64
#  10  O3       34460 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %% [markdown]
# Ternyata terdapat nilai yang missing di `changping_dframe`

# %% [markdown]
# Mencek fitur yang  datanya missing

# %%
changping_dframe.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       774
# PM10        582
# SO2         628
# NO2         667
# CO         1521
# O3          604
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %% [markdown]
# Fitur `changping_dframe` yang terdapat missing values :
#
#     - PM2.5
#     - PM10
#     - SO2
#     - NO2
#     - CO
#     - O3
#     - TEMP
#     - PRES
#     - DEWP
#     - RAIN
#     - wd
#     - WSPM

# %% [markdown]
# Sekarang kita cek duplikasi data di `changping_dframe`

# %%
print("Jumlah duplikasi data :", changping_dframe.duplicated().sum())
# Out:
# Jumlah duplikasi data : 0

# %% [markdown]
# Melihat Parameter Statistik

# %%
changping_dframe.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34290.000000  34482.000000  34436.000000  34397.000000  33543.000000
# mean      71.099743     94.657871     14.958906     44.182086   1152.301345
# std       72.326926     83.441738     20.975331     29.519796   1103.056282
# min        2.000000      2.000000      0.285600      1.847700    100.000000
# 25%       18.000000     34.000000      2.000000     22.000000    500.000000
# 50%       46.000000     72.000000      7.000000     36.000000    800.000000
# 75%      100.000000    131.000000     18.000000     60.358200   1400.000000
# max      882.000000    999.000000    310.000000    226.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  34460.000000  35011.000000  35014.000000  35011.000000  35013.000000
# mean      57.940003     13.686111   1007.760278      1.505495      0.060366
# std       54.316674     11.365313     10.225664     13.822099      0.752899
# min        0.214200    -16.600000    982.400000    -35.100000      0.000000
# 25%       15.636600      3.400000    999.300000    -10.200000      0.000000
# 50%       46.000000     14.700000   1007.400000      1.800000      0.000000
# 75%       80.000000     23.300000   1016.000000     14.200000      0.000000
# max      429.000000     41.400000   1036.500000     27.200000     52.100000
#
#                WSPM
# count  35021.000000
# mean       1.853836
# std        1.309808
# min        0.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.300000
# max       10.000000

# %% [markdown]
# Menilai Dataframe `dingling_dframe`

# %%
dingling_dframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34285 non-null  float64
#  6   PM10     34408 non-null  float64
#  7   SO2      34334 non-null  float64
#  8   NO2      33830 non-null  float64
#  9   CO       33052 non-null  float64
#  10  O3       33850 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %% [markdown]
# Ternyata terdapat nilai yang missing di `dingling_dframe`

# %% [markdown]
# Mencek fitur yang  datanya missing

# %%
dingling_dframe.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       779
# PM10        656
# SO2         730
# NO2        1234
# CO         2012
# O3         1214
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %% [markdown]
# Fitur `dingling_dframe` yang terdapat missing values :
#
#     - PM2.5
#     - PM10
#     - SO2
#     - NO2
#     - CO
#     - O3
#     - TEMP
#     - PRES
#     - DEWP
#     - RAIN
#     - wd
#     - WSPM

# %% [markdown]
# Sekarang kita cek duplikasi data di `dingling_dframe`

# %%
print("Jumlah duplikasi data :", dingling_dframe.duplicated().sum())
# Out:
# Jumlah duplikasi data : 0

# %% [markdown]
# Melihat Parameter Statistik

# %%
dingling_dframe.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34285.000000  34408.000000  34334.000000  33830.000000  33052.000000
# mean      65.989497     83.739723     11.749650     27.585467    904.896073
# std       72.267723     79.541685     15.519259     26.383882    903.306220
# min        3.000000      2.000000      0.285600      1.026500    100.000000
# 25%       14.000000     26.000000      2.000000      9.000000    300.000000
# 50%       41.000000     60.000000      5.000000     19.000000    600.000000
# 75%       93.000000    117.000000     15.000000     38.000000   1200.000000
# max      881.000000    905.000000    156.000000    205.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  33850.000000  35011.000000  35014.000000  35011.000000  35013.000000
# mean      68.548371     13.686111   1007.760278      1.505495      0.060366
# std       53.764424     11.365313     10.225664     13.822099      0.752899
# min        0.214200    -16.600000    982.400000    -35.100000      0.000000
# 25%       31.000000      3.400000    999.300000    -10.200000      0.000000
# 50%       61.000000     14.700000   1007.400000      1.800000      0.000000
# 75%       90.000000     23.300000   1016.000000     14.200000      0.000000
# max      500.000000     41.400000   1036.500000     27.200000     52.100000
#
#                WSPM
# count  35021.000000
# mean       1.853836
# std        1.309808
# min        0.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.300000
# max       10.000000

# %% [markdown]
# Menilai Dataframe `dongsi_dframe`

# %%
dongsi_dframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34314 non-null  float64
#  6   PM10     34511 non-null  float64
#  7   SO2      34401 non-null  float64
#  8   NO2      33463 non-null  float64
#  9   CO       31867 non-null  float64
#  10  O3       34400 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %% [markdown]
# Ternyata terdapat nilai yang missing di `dongsi_dframe`

# %% [markdown]
# Mencek fitur yang  datanya missing

# %%
dongsi_dframe.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       750
# PM10        553
# SO2         663
# NO2        1601
# CO         3197
# O3          664
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %% [markdown]
# Fitur `dongsi_dframe` yang terdapat missing values :
#
#     - PM2.5
#     - PM10
#     - SO2
#     - NO2
#     - CO
#     - O3
#     - TEMP
#     - PRES
#     - DEWP
#     - RAIN
#     - wd
#     - WSPM

# %% [markdown]
# Sekarang kita cek duplikasi data di `dongsi_dframe`

# %%
print("Jumlah duplikasi data :", dongsi_dframe.duplicated().sum())
# Out:
# Jumlah duplikasi data : 0

# %% [markdown]
# Melihat Parameter Statistik

# %%
dongsi_dframe.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34314.000000  34511.000000  34401.000000  33463.000000  31867.000000
# mean      86.194297    110.336742     18.531107     53.699443   1330.069131
# std       86.575127     98.219860     22.905655     33.959230   1191.305887
# min        3.000000      2.000000      0.285600      2.000000    100.000000
# 25%       22.000000     38.000000      4.000000     27.000000    600.000000
# 50%       61.000000     86.000000     10.000000     47.000000   1000.000000
# 75%      119.000000    151.000000     24.000000     73.000000   1700.000000
# max      737.000000    955.000000    300.000000    258.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  34400.000000  35044.000000  35044.000000  35044.000000  35044.000000
# mean      57.210637     13.671490   1012.547419      2.447535      0.064020
# std       58.033275     11.458418     10.266059     13.810696      0.786282
# min        0.642600    -16.800000    987.100000    -35.300000      0.000000
# 25%       12.000000      3.100000   1004.000000     -8.800000      0.000000
# 50%       44.125200     14.600000   1012.200000      3.000000      0.000000
# 75%       81.000000     23.500000   1020.900000     15.000000      0.000000
# max     1071.000000     41.100000   1042.000000     28.800000     46.400000
#
#                WSPM
# count  35050.000000
# mean       1.860785
# std        1.280368
# min        0.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.400000
# max       10.500000

# %% [markdown]
# Menilai Dataframe `guanyuan_dframe`

# %%
guanyuan_dframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34448 non-null  float64
#  6   PM10     34635 non-null  float64
#  7   SO2      34590 non-null  float64
#  8   NO2      34405 non-null  float64
#  9   CO       33311 non-null  float64
#  10  O3       33891 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %% [markdown]
# Ternyata terdapat nilai yang missing di `guanyuan_dframe`

# %% [markdown]
# Mencek fitur yang  datanya missing

# %%
guanyuan_dframe.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       616
# PM10        429
# SO2         474
# NO2         659
# CO         1753
# O3         1173
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %% [markdown]
# Fitur `guanyuan_dframe` yang terdapat missing values :
#
#     - PM2.5
#     - PM10
#     - SO2
#     - NO2
#     - CO
#     - O3
#     - TEMP
#     - PRES
#     - DEWP
#     - RAIN
#     - wd
#     - WSPM

# %% [markdown]
# Sekarang kita cek duplikasi data di `guanyuan_dframe`

# %%
print("Jumlah duplikasi data :", guanyuan_dframe.duplicated().sum())
# Out:
# Jumlah duplikasi data : 0

# %% [markdown]
# Melihat Parameter Statistik

# %%
guanyuan_dframe.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34448.000000  34635.000000  34590.000000  34405.000000  33311.000000
# mean      82.933372    109.023303     17.590941     57.901643   1271.294377
# std       80.933497     91.573709     23.600367     35.150857   1164.854945
# min        2.000000      2.000000      1.000000      2.000000    100.000000
# 25%       23.000000     40.000000      3.000000     31.000000    500.000000
# 50%       59.000000     89.000000      8.000000     51.000000    900.000000
# 75%      115.000000    149.000000     22.000000     78.000000   1600.000000
# max      680.000000    999.000000    293.000000    270.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  33891.000000  35044.000000  35044.000000  35044.000000  35044.000000
# mean      55.795044     13.584607   1011.846920      3.123062      0.067421
# std       57.436983     11.399097     10.404047     13.688896      0.910056
# min        0.214200    -16.800000    985.900000    -35.300000      0.000000
# 25%        7.000000      3.100000   1003.300000     -8.100000      0.000000
# 50%       41.000000     14.500000   1011.400000      3.800000      0.000000
# 75%       81.000000     23.300000   1020.100000     15.600000      0.000000
# max      415.000000     40.500000   1042.000000     28.500000     72.500000
#
#                WSPM
# count  35050.000000
# mean       1.708496
# std        1.204071
# min        0.000000
# 25%        0.900000
# 50%        1.400000
# 75%        2.200000
# max       11.200000

# %% [markdown]
# Menilai Dataframe `gucheng_dframe`

# %%
gucheng_dframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34418 non-null  float64
#  6   PM10     34683 non-null  float64
#  7   SO2      34557 non-null  float64
#  8   NO2      34396 non-null  float64
#  9   CO       33663 non-null  float64
#  10  O3       34335 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35013 non-null  float64
#  14  RAIN     35021 non-null  float64
#  15  wd       34905 non-null  object
#  16  WSPM     35022 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %% [markdown]
# Ternyata terdapat nilai yang missing di `gucheng_dframe`

# %% [markdown]
# Mencek fitur yang  datanya missing

# %%
gucheng_dframe.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       646
# PM10        381
# SO2         507
# NO2         668
# CO         1401
# O3          729
# TEMP         51
# PRES         50
# DEWP         51
# RAIN         43
# wd          159
# WSPM         42
# station       0
# dtype: int64

# %% [markdown]
# Fitur `gucheng_dframe` yang terdapat missing values :
#
#     - PM2.5
#     - PM10
#     - SO2
#     - NO2
#     - CO
#     - O3
#     - TEMP
#     - PRES
#     - DEWP
#     - RAIN
#     - wd
#     - WSPM

# %% [markdown]
# Sekarang kita cek duplikasi data di `gucheng_dframe`

# %%
print("Jumlah duplikasi data :", gucheng_dframe.duplicated().sum())
# Out:
# Jumlah duplikasi data : 0

# %% [markdown]
# Melihat Parameter Statistik

# %%
gucheng_dframe.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34418.000000  34683.000000  34557.000000  34396.000000  33663.000000
# mean      83.852089    118.861978     15.366162     55.871075   1323.974423
# std       82.796445     96.742626     21.204526     36.473860   1208.957772
# min        2.000000      2.000000      0.285600      2.000000    100.000000
# 25%       24.000000     45.000000      2.000000     26.000000    600.000000
# 50%       60.000000     99.000000      7.000000     50.000000    900.000000
# 75%      115.750000    167.000000     20.000000     79.000000   1600.000000
# max      770.000000    994.000000    500.000000    276.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  34335.000000  35013.000000  35014.000000  35013.000000  35021.000000
# mean      57.694879     13.864524   1008.829592      2.610442      0.064453
# std       57.019587     11.292857     10.103256     13.782991      0.838654
# min        0.214200    -15.600000    984.000000    -34.600000      0.000000
# 25%       10.000000      3.600000   1000.500000     -8.900000      0.000000
# 50%       45.000000     14.800000   1008.500000      3.000000      0.000000
# 75%       83.000000     23.500000   1017.000000     15.300000      0.000000
# max      450.000000     41.600000   1038.100000     27.400000     41.900000
#
#                WSPM
# count  35022.000000
# mean       1.343310
# std        1.151064
# min        0.000000
# 25%        0.600000
# 50%        1.000000
# 75%        1.800000
# max       12.000000

# %% [markdown]
# Menilai Dataframe `huairou_dframe`

# %%
huairou_dframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34111 non-null  float64
#  6   PM10     34287 non-null  float64
#  7   SO2      34084 non-null  float64
#  8   NO2      33425 non-null  float64
#  9   CO       33642 non-null  float64
#  10  O3       33913 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35011 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35009 non-null  float64
#  15  wd       34762 non-null  object
#  16  WSPM     35015 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %% [markdown]
# Ternyata terdapat nilai yang missing di `huairou_dframe`

# %% [markdown]
# Mencek fitur yang  datanya missing

# %%
huairou_dframe.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       953
# PM10        777
# SO2         980
# NO2        1639
# CO         1422
# O3         1151
# TEMP         51
# PRES         53
# DEWP         53
# RAIN         55
# wd          302
# WSPM         49
# station       0
# dtype: int64

# %% [markdown]
# Fitur `huairou_dframe` yang terdapat missing values :
#
#     - PM2.5
#     - PM10
#     - SO2
#     - NO2
#     - CO
#     - O3
#     - TEMP
#     - PRES
#     - DEWP
#     - RAIN
#     - wd
#     - WSPM

# %% [markdown]
# Sekarang kita cek duplikasi data di `huairou_dframe`

# %%
print("Jumlah duplikasi data :", huairou_dframe.duplicated().sum())
# Out:
# Jumlah duplikasi data : 0

# %% [markdown]
# Melihat Parameter Statistik

# %%
huairou_dframe.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34111.000000  34287.000000  34084.000000  33425.000000  33642.000000
# mean      69.626367     91.482690     12.121553     32.497250   1022.554545
# std       71.224916     83.289578     18.896912     26.489531    898.738241
# min        2.000000      2.000000      0.285600      1.026500    100.000000
# 25%       17.000000     28.000000      2.000000     12.000000    400.000000
# 50%       47.000000     69.000000      4.000000     25.000000    800.000000
# 75%       98.000000    131.000000     14.000000     46.000000   1300.000000
# max      762.000000    993.000000    315.000000    231.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  33913.000000  35013.000000  35011.000000  35011.000000  35009.000000
# mean      59.824713     12.445426   1007.598568      2.238619      0.067940
# std       54.605746     11.751103     10.022101     14.052541      0.849046
# min        0.214200    -19.900000    982.800000    -43.400000      0.000000
# 25%       18.000000      2.100000    999.300000     -9.600000      0.000000
# 50%       49.000000     13.600000   1007.300000      2.700000      0.000000
# 75%       83.000000     22.300000   1015.500000     15.300000      0.000000
# max      444.000000     40.300000   1036.500000     29.100000     45.900000
#
#                WSPM
# count  35015.000000
# mean       1.652021
# std        1.199143
# min        0.000000
# 25%        0.900000
# 50%        1.300000
# 75%        2.000000
# max       12.900000

# %% [markdown]
# Menilai Dataframe `nongzhanguan_dframe`

# %%
nongzhanguan_dframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34436 non-null  float64
#  6   PM10     34624 non-null  float64
#  7   SO2      34618 non-null  float64
#  8   NO2      34372 non-null  float64
#  9   CO       33858 non-null  float64
#  10  O3       34558 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %% [markdown]
# Ternyata terdapat nilai yang missing di `nongzhanguan_dframe`

# %% [markdown]
# Mencek fitur yang  datanya missing

# %%
nongzhanguan_dframe.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       628
# PM10        440
# SO2         446
# NO2         692
# CO         1206
# O3          506
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %% [markdown]
# Fitur `nongzhanguan_dframe` yang terdapat missing values :
#
#     - PM2.5
#     - PM10
#     - SO2
#     - NO2
#     - CO
#     - O3
#     - TEMP
#     - PRES
#     - DEWP
#     - RAIN
#     - wd
#     - WSPM

# %% [markdown]
# Sekarang kita cek duplikasi data di `nongzhanguan_dframe`

# %%
print("Jumlah duplikasi data :", nongzhanguan_dframe.duplicated().sum())
# Out:
# Jumlah duplikasi data : 0

# %% [markdown]
# Melihat Parameter Statistik

# %%
nongzhanguan_dframe.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34436.000000  34624.000000  34618.000000  34372.000000  33858.000000
# mean      84.838483    108.991096     18.689242     58.097172   1324.350198
# std       86.225344     95.341177     24.280665     36.297740   1245.166124
# min        2.000000      2.000000      0.571200      2.000000    100.000000
# 25%       22.000000     38.000000      3.000000     29.000000    500.000000
# 50%       59.000000     85.000000      9.000000     51.000000    900.000000
# 75%      116.000000    149.000000     23.000000     80.000000   1600.000000
# max      844.000000    995.000000    257.000000    273.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  34558.000000  35044.000000  35044.000000  35044.000000  35044.000000
# mean      58.534682     13.671490   1012.547419      2.447535      0.064020
# std       58.401448     11.458418     10.266059     13.810696      0.786282
# min        0.214200    -16.800000    987.100000    -35.300000      0.000000
# 25%       10.000000      3.100000   1004.000000     -8.800000      0.000000
# 50%       45.000000     14.600000   1012.200000      3.000000      0.000000
# 75%       84.000000     23.500000   1020.900000     15.000000      0.000000
# max      390.000000     41.100000   1042.000000     28.800000     46.400000
#
#                WSPM
# count  35050.000000
# mean       1.860785
# std        1.280368
# min        0.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.400000
# max       10.500000

# %% [markdown]
# Menilai Dataframe `shunyi_dframe`

# %%
shunyi_dframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34151 non-null  float64
#  6   PM10     34516 non-null  float64
#  7   SO2      33768 non-null  float64
#  8   NO2      33699 non-null  float64
#  9   CO       32886 non-null  float64
#  10  O3       33575 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35013 non-null  float64
#  13  DEWP     35010 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34581 non-null  object
#  16  WSPM     35020 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %% [markdown]
# Ternyata terdapat nilai yang missing di `shunyi_dframe`

# %% [markdown]
# Mencek fitur yang  datanya missing

# %%
shunyi_dframe.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       913
# PM10        548
# SO2        1296
# NO2        1365
# CO         2178
# O3         1489
# TEMP         51
# PRES         51
# DEWP         54
# RAIN         51
# wd          483
# WSPM         44
# station       0
# dtype: int64

# %% [markdown]
# Fitur `shunyi_dframe` yang terdapat missing values :
#
#     - PM2.5
#     - PM10
#     - SO2
#     - NO2
#     - CO
#     - O3
#     - TEMP
#     - PRES
#     - DEWP
#     - RAIN
#     - wd
#     - WSPM

# %% [markdown]
# Sekarang kita cek duplikasi data di `shunyi_dframe`

# %%
print("Jumlah duplikasi data :", shunyi_dframe.duplicated().sum())
# Out:
# Jumlah duplikasi data : 0

# %% [markdown]
# Melihat Parameter Statistik

# %%
shunyi_dframe.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34151.000000  34516.000000  33768.000000  33699.000000  32886.000000
# mean      79.491602     98.737026     13.572039     43.908865   1187.063979
# std       81.231739     89.143718     19.572068     30.996828   1156.374102
# min        2.000000      2.000000      0.285600      2.000000    100.000000
# 25%       19.000000     31.000000      2.000000     19.000000    400.000000
# 50%       55.000000     77.000000      5.000000     37.000000    800.000000
# 75%      112.000000    138.000000     17.000000     62.000000   1500.000000
# max      941.000000    999.000000    239.000000    258.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  33575.000000  35013.000000  35013.000000  35010.000000  35013.000000
# mean      55.201321     13.387969   1013.061938      2.465036      0.061094
# std       54.873726     11.483588     10.177339     13.726622      0.761668
# min        0.214200    -16.800000    988.000000    -36.000000      0.000000
# 25%       10.000000      3.000000   1004.700000     -8.800000      0.000000
# 50%       43.000000     14.400000   1012.700000      3.100000      0.000000
# 75%       77.000000     23.200000   1021.000000     15.100000      0.000000
# max      351.716400     40.600000   1042.800000     27.500000     37.300000
#
#                WSPM
# count  35020.000000
# mean       1.807533
# std        1.287817
# min        0.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.300000
# max       12.800000

# %% [markdown]
# Menilai Dataframe `tiantan_dframe`

# %%
tiantan_dframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34387 non-null  float64
#  6   PM10     34467 non-null  float64
#  7   SO2      33946 non-null  float64
#  8   NO2      34320 non-null  float64
#  9   CO       33938 non-null  float64
#  10  O3       34221 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %% [markdown]
# Ternyata terdapat nilai yang missing di `tiantan_dframe`

# %% [markdown]
# Mencek fitur yang  datanya missing

# %%
tiantan_dframe.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       677
# PM10        597
# SO2        1118
# NO2         744
# CO         1126
# O3          843
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %% [markdown]
# Fitur `tiantan_dframe` yang terdapat missing values :
#
#     - PM2.5
#     - PM10
#     - SO2
#     - NO2
#     - CO
#     - O3
#     - TEMP
#     - PRES
#     - DEWP
#     - RAIN
#     - wd
#     - WSPM

# %% [markdown]
# Sekarang kita cek duplikasi data di `tiantan_dframe`

# %%
print("Jumlah duplikasi data :", tiantan_dframe.duplicated().sum())
# Out:
# Jumlah duplikasi data : 0

# %% [markdown]
# Melihat Parameter Statistik

# %%
tiantan_dframe.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34387.000000  34467.000000  33946.000000  34320.000000  33938.000000
# mean      82.164911    106.363672     14.367615     53.162646   1298.303318
# std       80.921384     89.700157     20.144631     31.946224   1170.593297
# min        3.000000      2.000000      0.571200      2.000000    100.000000
# 25%       22.000000     41.000000      3.000000     28.000000    500.000000
# 50%       59.000000     85.000000      7.000000     47.000000    900.000000
# 75%      113.000000    144.000000     17.000000     71.000000   1600.000000
# max      821.000000    988.000000    273.000000    241.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  34221.000000  35044.000000  35044.000000  35044.000000  35044.000000
# mean      55.984297     13.671490   1012.547419      2.447535      0.064020
# std       59.081528     11.458418     10.266059     13.810696      0.786282
# min        0.428400    -16.800000    987.100000    -35.300000      0.000000
# 25%        8.000000      3.100000   1004.000000     -8.800000      0.000000
# 50%       40.000000     14.600000   1012.200000      3.000000      0.000000
# 75%       81.000000     23.500000   1020.900000     15.000000      0.000000
# max      674.000000     41.100000   1042.000000     28.800000     46.400000
#
#                WSPM
# count  35050.000000
# mean       1.860785
# std        1.280368
# min        0.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.400000
# max       10.500000

# %% [markdown]
# Menilai Dataframe `wanliu_dframe`

# %%
wanliu_dframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34682 non-null  float64
#  6   PM10     34780 non-null  float64
#  7   SO2      34489 non-null  float64
#  8   NO2      33994 non-null  float64
#  9   CO       33252 non-null  float64
#  10  O3       32957 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34941 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %% [markdown]
# Ternyata terdapat nilai yang missing di `wanliu_dframe`

# %% [markdown]
# Mencek fitur yang  datanya missing

# %%
wanliu_dframe.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       382
# PM10        284
# SO2         575
# NO2        1070
# CO         1812
# O3         2107
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd          123
# WSPM         14
# station       0
# dtype: int64

# %% [markdown]
# Fitur `wanliu_dframe` yang terdapat missing values :
#
#     - PM2.5
#     - PM10
#     - SO2
#     - NO2
#     - CO
#     - O3
#     - TEMP
#     - PRES
#     - DEWP
#     - RAIN
#     - wd
#     - WSPM

# %% [markdown]
# Sekarang kita cek duplikasi data di `wanliu_dframe`

# %%
print("Jumlah duplikasi data :", wanliu_dframe.duplicated().sum())
# Out:
# Jumlah duplikasi data : 0

# %% [markdown]
# Melihat Parameter Statistik

# %%
wanliu_dframe.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34682.000000  34780.000000  34489.000000  33994.000000  33252.000000
# mean      83.374716    110.464618     18.376481     65.258789   1319.353513
# std       81.905568     92.795065     22.609648     37.996088   1268.114331
# min        2.000000      2.000000      0.285600      1.642400    100.000000
# 25%       23.000000     40.000000      4.000000     36.000000    500.000000
# 50%       59.000000     88.000000     10.000000     60.000000    900.000000
# 75%      116.000000    153.000000     23.000000     88.000000   1600.000000
# max      957.000000    951.000000    282.000000    264.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  32957.000000  35044.000000  35044.000000  35044.000000  35044.000000
# mean      48.873614     13.428865   1011.097536      3.266588      0.068263
# std       55.111740     11.346931     10.355247     13.678060      0.896726
# min        0.214200    -15.800000    985.900000    -34.900000      0.000000
# 25%        4.000000      3.200000   1002.500000     -8.100000      0.000000
# 50%       32.000000     14.300000   1010.800000      4.000000      0.000000
# 75%       73.000000     22.900000   1019.400000     15.800000      0.000000
# max      364.000000     40.500000   1040.300000     28.500000     72.500000
#
#                WSPM
# count  35050.000000
# mean       1.501215
# std        1.104472
# min        0.000000
# 25%        0.800000
# 50%        1.200000
# 75%        2.000000
# max       11.200000

# %% [markdown]
# Menilai Dataframe `wanshouxigong_dframe`

# %%
wanshouxigong_dframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34368 non-null  float64
#  6   PM10     34580 non-null  float64
#  7   SO2      34395 non-null  float64
#  8   NO2      34310 non-null  float64
#  9   CO       33767 non-null  float64
#  10  O3       33986 non-null  float64
#  11  TEMP     35045 non-null  float64
#  12  PRES     35045 non-null  float64
#  13  DEWP     35045 non-null  float64
#  14  RAIN     35045 non-null  float64
#  15  wd       34985 non-null  object
#  16  WSPM     35051 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %% [markdown]
# Ternyata terdapat nilai yang missing di `wanshouxigong_dframe`

# %% [markdown]
# Mencek fitur yang  datanya missing

# %%
wanshouxigong_dframe.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       696
# PM10        484
# SO2         669
# NO2         754
# CO         1297
# O3         1078
# TEMP         19
# PRES         19
# DEWP         19
# RAIN         19
# wd           79
# WSPM         13
# station       0
# dtype: int64

# %% [markdown]
# Fitur `wanshouxigong_dframe` yang terdapat missing values :
#
#     - PM2.5
#     - PM10
#     - SO2
#     - NO2
#     - CO
#     - O3
#     - TEMP
#     - PRES
#     - DEWP
#     - RAIN
#     - wd
#     - WSPM

# %% [markdown]
# Sekarang kita cek duplikasi data di `wanshouxigong_dframe`

# %%
print("Jumlah duplikasi data :", wanshouxigong_dframe.duplicated().sum())
# Out:
# Jumlah duplikasi data : 0

# %% [markdown]
# Melihat Parameter Statistik

# %%
wanshouxigong_dframe.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2          NO2            CO  \
# count  34368.000000  34580.000000  34395.000000  34310.00000  33767.000000
# mean      85.024136    112.223459     17.148603     55.52956   1370.395031
# std       85.975981     97.593210     23.940834     35.80805   1223.139114
# min        3.000000      2.000000      0.285600      2.00000    100.000000
# 25%       23.000000     39.000000      3.000000     28.00000    600.000000
# 50%       60.000000     91.000000      8.000000     49.00000   1000.000000
# 75%      116.000000    154.000000     21.000000     77.00000   1700.000000
# max      999.000000    961.000000    411.000000    251.00000   9800.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  33986.000000  35045.000000  35045.000000  35045.000000  35045.000000
# mean      56.229904     13.784477   1011.511804      2.707442      0.064320
# std       57.082710     11.385156     10.570928     13.704139      0.796981
# min        0.214200    -16.800000    985.100000    -35.300000      0.000000
# 25%        8.000000      3.400000   1002.800000     -8.500000      0.000000
# 50%       42.000000     14.800000   1011.000000      3.300000      0.000000
# 75%       82.000000     23.500000   1020.000000     15.200000      0.000000
# max      358.000000     40.600000   1042.000000     28.500000     46.400000
#
#                WSPM
# count  35051.000000
# mean       1.745314
# std        1.206355
# min        0.000000
# 25%        0.900000
# 50%        1.400000
# 75%        2.300000
# max       13.200000

# %% [markdown]
# **Insight:**
# - Semua stasiun pemantauan kualitas udara memiliki missing value di fitur yang sama yaitu :
#     - PM2.5
#     - PM10
#     - SO2
#     - NO2
#     - CO
#     - O3
#     - TEMP
#     - PRES
#     - DEWP
#     - RAIN
#     - wd
#     - WSPM
# - Tidak ada dataframe yang memiiki duplikasi data, serta tipe data untuk tiap fitur sudah tepat

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Membersihkan Missing Value dari `aothizhongxin_dframe`
#
# Saya mengganti data kualitatif dengan mean() karena dataset mengandung outlier sehingga tidak mempengaruhi parameter statistik yang lain, sementara untuk data kategori mengganti nya dengan yang sering muncul di fiturnya

# %%
aothizhongxin_dframe["PM2.5"].fillna(value=aothizhongxin_dframe["PM2.5"].mean(), inplace=True)
aothizhongxin_dframe.PM10.fillna(value=aothizhongxin_dframe.PM10.mean(), inplace=True)
aothizhongxin_dframe.SO2.fillna(value=aothizhongxin_dframe.SO2.mean(), inplace=True)
aothizhongxin_dframe.NO2.fillna(value=aothizhongxin_dframe.NO2.mean(), inplace=True)
aothizhongxin_dframe.CO.fillna(value=aothizhongxin_dframe.CO.mean(), inplace=True)
aothizhongxin_dframe.O3.fillna(value=aothizhongxin_dframe.O3.mean(), inplace=True)
aothizhongxin_dframe.TEMP.fillna(value=aothizhongxin_dframe.TEMP.mean(), inplace=True)
aothizhongxin_dframe.PRES.fillna(value=aothizhongxin_dframe.PRES.mean(), inplace=True)
aothizhongxin_dframe.DEWP.fillna(value=aothizhongxin_dframe.DEWP.mean(), inplace=True)
aothizhongxin_dframe.RAIN.fillna(value=aothizhongxin_dframe.RAIN.mean(), inplace=True)
aothizhongxin_dframe.wd.fillna(value="NE", inplace=True)
aothizhongxin_dframe.WSPM.fillna(value=aothizhongxin_dframe.WSPM.mean(), inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\348605031.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   aothizhongxin_dframe["PM2.5"].fillna(value=aothizhongxin_dframe["PM2.5"].mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\348605031.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   aothizhongxin_dframe.PM10.fillna(value=aothizhongxin_dframe.PM10.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\348605031.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   aothizhongxin_dframe.SO2.fillna(value=aothizhongxin_dframe.SO2.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\348605031.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   aothizhongxin_dframe.NO2.fillna(value=aothizhongxin_dframe.NO2.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\348605031.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   aothizhongxin_dframe.CO.fillna(value=aothizhongxin_dframe.CO.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\348605031.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   aothizhongxin_dframe.O3.fillna(value=aothizhongxin_dframe.O3.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\348605031.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   aothizhongxin_dframe.TEMP.fillna(value=aothizhongxin_dframe.TEMP.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\348605031.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   aothizhongxin_dframe.PRES.fillna(value=aothizhongxin_dframe.PRES.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\348605031.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   aothizhongxin_dframe.DEWP.fillna(value=aothizhongxin_dframe.DEWP.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\348605031.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   aothizhongxin_dframe.RAIN.fillna(value=aothizhongxin_dframe.RAIN.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\348605031.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   aothizhongxin_dframe.wd.fillna(value="NE", inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\348605031.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   aothizhongxin_dframe.WSPM.fillna(value=aothizhongxin_dframe.WSPM.mean(), inplace=True)

# %% [markdown]
# Memeriksa apakah masih terfapat missing value

# %%
aothizhongxin_dframe.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# Membersihkan Missing Value dari `changping_dframe`
#
# Saya mengganti data kualitatif dengan mean() karena dataset mengandung outlier sehingga tidak mempengaruhi parameter statistik yang lain, sementara untuk data kategori mengganti nya dengan yang sering muncul di fiturnya

# %%
changping_dframe["PM2.5"].fillna(value=changping_dframe["PM2.5"].mean(), inplace=True)
changping_dframe.PM10.fillna(value=changping_dframe.PM10.mean(), inplace=True)
changping_dframe.SO2.fillna(value=changping_dframe.SO2.mean(), inplace=True)
changping_dframe.NO2.fillna(value=changping_dframe.NO2.mean(), inplace=True)
changping_dframe.CO.fillna(value=changping_dframe.CO.mean(), inplace=True)
changping_dframe.O3.fillna(value=changping_dframe.O3.mean(), inplace=True)
changping_dframe.TEMP.fillna(value=changping_dframe.TEMP.mean(), inplace=True)
changping_dframe.PRES.fillna(value=changping_dframe.PRES.mean(), inplace=True)
changping_dframe.DEWP.fillna(value=changping_dframe.DEWP.mean(), inplace=True)
changping_dframe.RAIN.fillna(value=changping_dframe.RAIN.mean(), inplace=True)
changping_dframe.wd.fillna(value="NNW", inplace=True)
changping_dframe.WSPM.fillna(value=changping_dframe.WSPM.mean(), inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\329359955.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   changping_dframe["PM2.5"].fillna(value=changping_dframe["PM2.5"].mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\329359955.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   changping_dframe.PM10.fillna(value=changping_dframe.PM10.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\329359955.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   changping_dframe.SO2.fillna(value=changping_dframe.SO2.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\329359955.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   changping_dframe.NO2.fillna(value=changping_dframe.NO2.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\329359955.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   changping_dframe.CO.fillna(value=changping_dframe.CO.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\329359955.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   changping_dframe.O3.fillna(value=changping_dframe.O3.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\329359955.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   changping_dframe.TEMP.fillna(value=changping_dframe.TEMP.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\329359955.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   changping_dframe.PRES.fillna(value=changping_dframe.PRES.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\329359955.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   changping_dframe.DEWP.fillna(value=changping_dframe.DEWP.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\329359955.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   changping_dframe.RAIN.fillna(value=changping_dframe.RAIN.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\329359955.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   changping_dframe.wd.fillna(value="NNW", inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\329359955.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   changping_dframe.WSPM.fillna(value=changping_dframe.WSPM.mean(), inplace=True)

# %% [markdown]
# Memeriksa apakah masih terfapat missing value

# %%
changping_dframe.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# Membersihkan Missing Value dari `dingling_dframe`
#
# Saya mengganti data kualitatif dengan mean() karena dataset mengandung outlier sehingga tidak mempengaruhi parameter statistik yang lain, sementara untuk data kategori mengganti nya dengan yang sering muncul di fiturnya

# %%
dingling_dframe["PM2.5"].fillna(value=dingling_dframe["PM2.5"].mean(), inplace=True)
dingling_dframe.PM10.fillna(value=dingling_dframe.PM10.mean(), inplace=True)
dingling_dframe.SO2.fillna(value=dingling_dframe.SO2.mean(), inplace=True)
dingling_dframe.NO2.fillna(value=dingling_dframe.NO2.mean(), inplace=True)
dingling_dframe.CO.fillna(value=dingling_dframe.CO.mean(), inplace=True)
dingling_dframe.O3.fillna(value=dingling_dframe.O3.mean(), inplace=True)
dingling_dframe.TEMP.fillna(value=dingling_dframe.TEMP.mean(), inplace=True)
dingling_dframe.PRES.fillna(value=dingling_dframe.PRES.mean(), inplace=True)
dingling_dframe.DEWP.fillna(value=dingling_dframe.DEWP.mean(), inplace=True)
dingling_dframe.RAIN.fillna(value=dingling_dframe.RAIN.mean(), inplace=True)
dingling_dframe.wd.fillna(value="NNW", inplace=True)
dingling_dframe.WSPM.fillna(value=dingling_dframe.WSPM.mean(), inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3868763502.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dingling_dframe["PM2.5"].fillna(value=dingling_dframe["PM2.5"].mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3868763502.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dingling_dframe.PM10.fillna(value=dingling_dframe.PM10.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3868763502.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dingling_dframe.SO2.fillna(value=dingling_dframe.SO2.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3868763502.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dingling_dframe.NO2.fillna(value=dingling_dframe.NO2.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3868763502.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dingling_dframe.CO.fillna(value=dingling_dframe.CO.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3868763502.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dingling_dframe.O3.fillna(value=dingling_dframe.O3.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3868763502.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dingling_dframe.TEMP.fillna(value=dingling_dframe.TEMP.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3868763502.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dingling_dframe.PRES.fillna(value=dingling_dframe.PRES.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3868763502.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dingling_dframe.DEWP.fillna(value=dingling_dframe.DEWP.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3868763502.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dingling_dframe.RAIN.fillna(value=dingling_dframe.RAIN.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3868763502.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dingling_dframe.wd.fillna(value="NNW", inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3868763502.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dingling_dframe.WSPM.fillna(value=dingling_dframe.WSPM.mean(), inplace=True)

# %% [markdown]
# Memeriksa apakah masih terfapat missing value

# %%
dingling_dframe.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# Membersihkan Missing Value dari `dongsi_dframe`
#
# Saya mengganti data kualitatif dengan mean() karena dataset mengandung outlier sehingga tidak mempengaruhi parameter statistik yang lain, sementara untuk data kategori mengganti nya dengan yang sering muncul di fiturnya

# %%
dongsi_dframe["PM2.5"].fillna(value=dongsi_dframe["PM2.5"].mean(), inplace=True)
dongsi_dframe.PM10.fillna(value=dongsi_dframe.PM10.mean(), inplace=True)
dongsi_dframe.SO2.fillna(value=dongsi_dframe.SO2.mean(), inplace=True)
dongsi_dframe.NO2.fillna(value=dongsi_dframe.NO2.mean(), inplace=True)
dongsi_dframe.CO.fillna(value=dongsi_dframe.CO.mean(), inplace=True)
dongsi_dframe.O3.fillna(value=dongsi_dframe.O3.mean(), inplace=True)
dongsi_dframe.TEMP.fillna(value=dongsi_dframe.TEMP.mean(), inplace=True)
dongsi_dframe.PRES.fillna(value=dongsi_dframe.PRES.mean(), inplace=True)
dongsi_dframe.DEWP.fillna(value=dongsi_dframe.DEWP.mean(), inplace=True)
dongsi_dframe.RAIN.fillna(value=dongsi_dframe.RAIN.mean(), inplace=True)
dongsi_dframe.wd.fillna(value="NNW", inplace=True)
dongsi_dframe.WSPM.fillna(value=dongsi_dframe.WSPM.mean(), inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2274009258.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dongsi_dframe["PM2.5"].fillna(value=dongsi_dframe["PM2.5"].mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2274009258.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dongsi_dframe.PM10.fillna(value=dongsi_dframe.PM10.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2274009258.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dongsi_dframe.SO2.fillna(value=dongsi_dframe.SO2.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2274009258.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dongsi_dframe.NO2.fillna(value=dongsi_dframe.NO2.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2274009258.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dongsi_dframe.CO.fillna(value=dongsi_dframe.CO.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2274009258.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dongsi_dframe.O3.fillna(value=dongsi_dframe.O3.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2274009258.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dongsi_dframe.TEMP.fillna(value=dongsi_dframe.TEMP.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2274009258.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dongsi_dframe.PRES.fillna(value=dongsi_dframe.PRES.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2274009258.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dongsi_dframe.DEWP.fillna(value=dongsi_dframe.DEWP.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2274009258.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dongsi_dframe.RAIN.fillna(value=dongsi_dframe.RAIN.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2274009258.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dongsi_dframe.wd.fillna(value="NNW", inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2274009258.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dongsi_dframe.WSPM.fillna(value=dongsi_dframe.WSPM.mean(), inplace=True)

# %% [markdown]
# Memeriksa apakah masih terfapat missing value

# %%
dongsi_dframe.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# Membersihkan Missing Value dari `guanyuan_dframe`
#
# Saya mengganti data kualitatif dengan mean() karena dataset mengandung outlier sehingga tidak mempengaruhi parameter statistik yang lain, sementara untuk data kategori mengganti nya dengan yang sering muncul di fiturnya

# %%
guanyuan_dframe["PM2.5"].fillna(value=guanyuan_dframe["PM2.5"].mean(), inplace=True)
guanyuan_dframe.PM10.fillna(value=guanyuan_dframe.PM10.mean(), inplace=True)
guanyuan_dframe.SO2.fillna(value=guanyuan_dframe.SO2.mean(), inplace=True)
guanyuan_dframe.NO2.fillna(value=guanyuan_dframe.NO2.mean(), inplace=True)
guanyuan_dframe.CO.fillna(value=guanyuan_dframe.CO.mean(), inplace=True)
guanyuan_dframe.O3.fillna(value=guanyuan_dframe.O3.mean(), inplace=True)
guanyuan_dframe.TEMP.fillna(value=guanyuan_dframe.TEMP.mean(), inplace=True)
guanyuan_dframe.PRES.fillna(value=guanyuan_dframe.PRES.mean(), inplace=True)
guanyuan_dframe.DEWP.fillna(value=guanyuan_dframe.DEWP.mean(), inplace=True)
guanyuan_dframe.RAIN.fillna(value=guanyuan_dframe.RAIN.mean(), inplace=True)
guanyuan_dframe.wd.fillna(value="NNW", inplace=True)
guanyuan_dframe.WSPM.fillna(value=guanyuan_dframe.WSPM.mean(), inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3769829075.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   guanyuan_dframe["PM2.5"].fillna(value=guanyuan_dframe["PM2.5"].mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3769829075.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   guanyuan_dframe.PM10.fillna(value=guanyuan_dframe.PM10.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3769829075.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   guanyuan_dframe.SO2.fillna(value=guanyuan_dframe.SO2.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3769829075.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   guanyuan_dframe.NO2.fillna(value=guanyuan_dframe.NO2.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3769829075.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   guanyuan_dframe.CO.fillna(value=guanyuan_dframe.CO.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3769829075.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   guanyuan_dframe.O3.fillna(value=guanyuan_dframe.O3.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3769829075.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   guanyuan_dframe.TEMP.fillna(value=guanyuan_dframe.TEMP.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3769829075.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   guanyuan_dframe.PRES.fillna(value=guanyuan_dframe.PRES.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3769829075.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   guanyuan_dframe.DEWP.fillna(value=guanyuan_dframe.DEWP.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3769829075.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   guanyuan_dframe.RAIN.fillna(value=guanyuan_dframe.RAIN.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3769829075.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   guanyuan_dframe.wd.fillna(value="NNW", inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3769829075.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   guanyuan_dframe.WSPM.fillna(value=guanyuan_dframe.WSPM.mean(), inplace=True)

# %% [markdown]
# Memeriksa apakah masih terfapat missing value

# %%
guanyuan_dframe.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# Membersihkan Missing Value dari `gucheng_dframe`
#
# Saya mengganti data kualitatif dengan mean() karena dataset mengandung outlier sehingga tidak mempengaruhi parameter statistik yang lain, sementara untuk data kategori mengganti nya dengan yang sering muncul di fiturnya

# %%
gucheng_dframe["PM2.5"].fillna(value=gucheng_dframe["PM2.5"].mean(), inplace=True)
gucheng_dframe.PM10.fillna(value=gucheng_dframe.PM10.mean(), inplace=True)
gucheng_dframe.SO2.fillna(value=gucheng_dframe.SO2.mean(), inplace=True)
gucheng_dframe.NO2.fillna(value=gucheng_dframe.NO2.mean(), inplace=True)
gucheng_dframe.CO.fillna(value=gucheng_dframe.CO.mean(), inplace=True)
gucheng_dframe.O3.fillna(value=gucheng_dframe.O3.mean(), inplace=True)
gucheng_dframe.TEMP.fillna(value=gucheng_dframe.TEMP.mean(), inplace=True)
gucheng_dframe.PRES.fillna(value=gucheng_dframe.PRES.mean(), inplace=True)
gucheng_dframe.DEWP.fillna(value=gucheng_dframe.DEWP.mean(), inplace=True)
gucheng_dframe.RAIN.fillna(value=gucheng_dframe.RAIN.mean(), inplace=True)
gucheng_dframe.wd.fillna(value="NNW", inplace=True)
gucheng_dframe.WSPM.fillna(value=gucheng_dframe.WSPM.mean(), inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3018613429.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   gucheng_dframe["PM2.5"].fillna(value=gucheng_dframe["PM2.5"].mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3018613429.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   gucheng_dframe.PM10.fillna(value=gucheng_dframe.PM10.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3018613429.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   gucheng_dframe.SO2.fillna(value=gucheng_dframe.SO2.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3018613429.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   gucheng_dframe.NO2.fillna(value=gucheng_dframe.NO2.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3018613429.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   gucheng_dframe.CO.fillna(value=gucheng_dframe.CO.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3018613429.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   gucheng_dframe.O3.fillna(value=gucheng_dframe.O3.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3018613429.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   gucheng_dframe.TEMP.fillna(value=gucheng_dframe.TEMP.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3018613429.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   gucheng_dframe.PRES.fillna(value=gucheng_dframe.PRES.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3018613429.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   gucheng_dframe.DEWP.fillna(value=gucheng_dframe.DEWP.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3018613429.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   gucheng_dframe.RAIN.fillna(value=gucheng_dframe.RAIN.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3018613429.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   gucheng_dframe.wd.fillna(value="NNW", inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3018613429.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   gucheng_dframe.WSPM.fillna(value=gucheng_dframe.WSPM.mean(), inplace=True)

# %% [markdown]
# Memeriksa apakah masih terfapat missing value

# %%
gucheng_dframe.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# Membersihkan Missing Value dari `huairou_dframe`
#
# Saya mengganti data kualitatif dengan mean() karena dataset mengandung outlier sehingga tidak mempengaruhi parameter statistik yang lain, sementara untuk data kategori mengganti nya dengan yang sering muncul di fiturnya

# %%
huairou_dframe["PM2.5"].fillna(value=huairou_dframe["PM2.5"].mean(), inplace=True)
huairou_dframe.PM10.fillna(value=huairou_dframe.PM10.mean(), inplace=True)
huairou_dframe.SO2.fillna(value=huairou_dframe.SO2.mean(), inplace=True)
huairou_dframe.NO2.fillna(value=huairou_dframe.NO2.mean(), inplace=True)
huairou_dframe.CO.fillna(value=huairou_dframe.CO.mean(), inplace=True)
huairou_dframe.O3.fillna(value=huairou_dframe.O3.mean(), inplace=True)
huairou_dframe.TEMP.fillna(value=huairou_dframe.TEMP.mean(), inplace=True)
huairou_dframe.PRES.fillna(value=huairou_dframe.PRES.mean(), inplace=True)
huairou_dframe.DEWP.fillna(value=huairou_dframe.DEWP.mean(), inplace=True)
huairou_dframe.RAIN.fillna(value=huairou_dframe.RAIN.mean(), inplace=True)
huairou_dframe.wd.fillna(value="NNW", inplace=True)
huairou_dframe.WSPM.fillna(value=huairou_dframe.WSPM.mean(), inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3169540868.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   huairou_dframe["PM2.5"].fillna(value=huairou_dframe["PM2.5"].mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3169540868.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   huairou_dframe.PM10.fillna(value=huairou_dframe.PM10.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3169540868.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   huairou_dframe.SO2.fillna(value=huairou_dframe.SO2.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3169540868.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   huairou_dframe.NO2.fillna(value=huairou_dframe.NO2.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3169540868.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   huairou_dframe.CO.fillna(value=huairou_dframe.CO.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3169540868.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   huairou_dframe.O3.fillna(value=huairou_dframe.O3.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3169540868.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   huairou_dframe.TEMP.fillna(value=huairou_dframe.TEMP.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3169540868.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   huairou_dframe.PRES.fillna(value=huairou_dframe.PRES.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3169540868.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   huairou_dframe.DEWP.fillna(value=huairou_dframe.DEWP.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3169540868.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   huairou_dframe.RAIN.fillna(value=huairou_dframe.RAIN.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3169540868.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   huairou_dframe.wd.fillna(value="NNW", inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3169540868.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   huairou_dframe.WSPM.fillna(value=huairou_dframe.WSPM.mean(), inplace=True)

# %% [markdown]
# Memeriksa apakah masih terfapat missing value

# %%
huairou_dframe.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# Membersihkan Missing Value dari `nongzhanguan_dframe`
#
# Saya mengganti data kualitatif dengan mean() karena dataset mengandung outlier sehingga tidak mempengaruhi parameter statistik yang lain, sementara untuk data kategori mengganti nya dengan yang sering muncul di fiturnya

# %%
nongzhanguan_dframe["PM2.5"].fillna(value=nongzhanguan_dframe["PM2.5"].mean(), inplace=True)
nongzhanguan_dframe.PM10.fillna(value=nongzhanguan_dframe.PM10.mean(), inplace=True)
nongzhanguan_dframe.SO2.fillna(value=nongzhanguan_dframe.SO2.mean(), inplace=True)
nongzhanguan_dframe.NO2.fillna(value=nongzhanguan_dframe.NO2.mean(), inplace=True)
nongzhanguan_dframe.CO.fillna(value=nongzhanguan_dframe.CO.mean(), inplace=True)
nongzhanguan_dframe.O3.fillna(value=nongzhanguan_dframe.O3.mean(), inplace=True)
nongzhanguan_dframe.TEMP.fillna(value=nongzhanguan_dframe.TEMP.mean(), inplace=True)
nongzhanguan_dframe.PRES.fillna(value=nongzhanguan_dframe.PRES.mean(), inplace=True)
nongzhanguan_dframe.DEWP.fillna(value=nongzhanguan_dframe.DEWP.mean(), inplace=True)
nongzhanguan_dframe.RAIN.fillna(value=nongzhanguan_dframe.RAIN.mean(), inplace=True)
nongzhanguan_dframe.wd.fillna(value="NNW", inplace=True)
nongzhanguan_dframe.WSPM.fillna(value=nongzhanguan_dframe.WSPM.mean(), inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2018614098.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   nongzhanguan_dframe["PM2.5"].fillna(value=nongzhanguan_dframe["PM2.5"].mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2018614098.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   nongzhanguan_dframe.PM10.fillna(value=nongzhanguan_dframe.PM10.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2018614098.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   nongzhanguan_dframe.SO2.fillna(value=nongzhanguan_dframe.SO2.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2018614098.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   nongzhanguan_dframe.NO2.fillna(value=nongzhanguan_dframe.NO2.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2018614098.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   nongzhanguan_dframe.CO.fillna(value=nongzhanguan_dframe.CO.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2018614098.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   nongzhanguan_dframe.O3.fillna(value=nongzhanguan_dframe.O3.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2018614098.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   nongzhanguan_dframe.TEMP.fillna(value=nongzhanguan_dframe.TEMP.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2018614098.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   nongzhanguan_dframe.PRES.fillna(value=nongzhanguan_dframe.PRES.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2018614098.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   nongzhanguan_dframe.DEWP.fillna(value=nongzhanguan_dframe.DEWP.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2018614098.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   nongzhanguan_dframe.RAIN.fillna(value=nongzhanguan_dframe.RAIN.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2018614098.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   nongzhanguan_dframe.wd.fillna(value="NNW", inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2018614098.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   nongzhanguan_dframe.WSPM.fillna(value=nongzhanguan_dframe.WSPM.mean(), inplace=True)

# %% [markdown]
# Memeriksa apakah masih terfapat missing value

# %%
nongzhanguan_dframe.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# Membersihkan Missing Value dari `shunyi_dframe`
#
# Saya mengganti data kualitatif dengan mean() karena dataset mengandung outlier sehingga tidak mempengaruhi parameter statistik yang lain, sementara untuk data kategori mengganti nya dengan yang sering muncul di fiturnya

# %%
shunyi_dframe["PM2.5"].fillna(value=shunyi_dframe["PM2.5"].mean(), inplace=True)
shunyi_dframe.PM10.fillna(value=shunyi_dframe.PM10.mean(), inplace=True)
shunyi_dframe.SO2.fillna(value=shunyi_dframe.SO2.mean(), inplace=True)
shunyi_dframe.NO2.fillna(value=shunyi_dframe.NO2.mean(), inplace=True)
shunyi_dframe.CO.fillna(value=shunyi_dframe.CO.mean(), inplace=True)
shunyi_dframe.O3.fillna(value=shunyi_dframe.O3.mean(), inplace=True)
shunyi_dframe.TEMP.fillna(value=shunyi_dframe.TEMP.mean(), inplace=True)
shunyi_dframe.PRES.fillna(value=shunyi_dframe.PRES.mean(), inplace=True)
shunyi_dframe.DEWP.fillna(value=shunyi_dframe.DEWP.mean(), inplace=True)
shunyi_dframe.RAIN.fillna(value=shunyi_dframe.RAIN.mean(), inplace=True)
shunyi_dframe.wd.fillna(value="NNW", inplace=True)
shunyi_dframe.WSPM.fillna(value=shunyi_dframe.WSPM.mean(), inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\4146721966.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   shunyi_dframe["PM2.5"].fillna(value=shunyi_dframe["PM2.5"].mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\4146721966.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   shunyi_dframe.PM10.fillna(value=shunyi_dframe.PM10.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\4146721966.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   shunyi_dframe.SO2.fillna(value=shunyi_dframe.SO2.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\4146721966.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   shunyi_dframe.NO2.fillna(value=shunyi_dframe.NO2.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\4146721966.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   shunyi_dframe.CO.fillna(value=shunyi_dframe.CO.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\4146721966.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   shunyi_dframe.O3.fillna(value=shunyi_dframe.O3.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\4146721966.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   shunyi_dframe.TEMP.fillna(value=shunyi_dframe.TEMP.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\4146721966.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   shunyi_dframe.PRES.fillna(value=shunyi_dframe.PRES.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\4146721966.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   shunyi_dframe.DEWP.fillna(value=shunyi_dframe.DEWP.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\4146721966.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   shunyi_dframe.RAIN.fillna(value=shunyi_dframe.RAIN.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\4146721966.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   shunyi_dframe.wd.fillna(value="NNW", inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\4146721966.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   shunyi_dframe.WSPM.fillna(value=shunyi_dframe.WSPM.mean(), inplace=True)

# %% [markdown]
# Memeriksa apakah masih terfapat missing value

# %%
shunyi_dframe.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# Membersihkan Missing Value dari `tiantan_dframe`
#
# Saya mengganti data kualitatif dengan mean() karena dataset mengandung outlier sehingga tidak mempengaruhi parameter statistik yang lain, sementara untuk data kategori mengganti nya dengan yang sering muncul di fiturnya

# %%
tiantan_dframe["PM2.5"].fillna(value=tiantan_dframe["PM2.5"].mean(), inplace=True)
tiantan_dframe.PM10.fillna(value=tiantan_dframe.PM10.mean(), inplace=True)
tiantan_dframe.SO2.fillna(value=tiantan_dframe.SO2.mean(), inplace=True)
tiantan_dframe.NO2.fillna(value=tiantan_dframe.NO2.mean(), inplace=True)
tiantan_dframe.CO.fillna(value=tiantan_dframe.CO.mean(), inplace=True)
tiantan_dframe.O3.fillna(value=tiantan_dframe.O3.mean(), inplace=True)
tiantan_dframe.TEMP.fillna(value=tiantan_dframe.TEMP.mean(), inplace=True)
tiantan_dframe.PRES.fillna(value=tiantan_dframe.PRES.mean(), inplace=True)
tiantan_dframe.DEWP.fillna(value=tiantan_dframe.DEWP.mean(), inplace=True)
tiantan_dframe.RAIN.fillna(value=tiantan_dframe.RAIN.mean(), inplace=True)
tiantan_dframe.wd.fillna(value="NNW", inplace=True)
tiantan_dframe.WSPM.fillna(value=tiantan_dframe.WSPM.mean(), inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3522608521.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   tiantan_dframe["PM2.5"].fillna(value=tiantan_dframe["PM2.5"].mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3522608521.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   tiantan_dframe.PM10.fillna(value=tiantan_dframe.PM10.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3522608521.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   tiantan_dframe.SO2.fillna(value=tiantan_dframe.SO2.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3522608521.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   tiantan_dframe.NO2.fillna(value=tiantan_dframe.NO2.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3522608521.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   tiantan_dframe.CO.fillna(value=tiantan_dframe.CO.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3522608521.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   tiantan_dframe.O3.fillna(value=tiantan_dframe.O3.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3522608521.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   tiantan_dframe.TEMP.fillna(value=tiantan_dframe.TEMP.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3522608521.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   tiantan_dframe.PRES.fillna(value=tiantan_dframe.PRES.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3522608521.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   tiantan_dframe.DEWP.fillna(value=tiantan_dframe.DEWP.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3522608521.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   tiantan_dframe.RAIN.fillna(value=tiantan_dframe.RAIN.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3522608521.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   tiantan_dframe.wd.fillna(value="NNW", inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\3522608521.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   tiantan_dframe.WSPM.fillna(value=tiantan_dframe.WSPM.mean(), inplace=True)

# %% [markdown]
# Memeriksa apakah masih terfapat missing value

# %%
tiantan_dframe.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# Membersihkan Missing Value dari `wanliu_dframe`
#
# Saya mengganti data kualitatif dengan mean() karena dataset mengandung outlier sehingga tidak mempengaruhi parameter statistik yang lain, sementara untuk data kategori mengganti nya dengan yang sering muncul di fiturnya

# %%
wanliu_dframe["PM2.5"].fillna(value=wanliu_dframe["PM2.5"].mean(), inplace=True)
wanliu_dframe.PM10.fillna(value=wanliu_dframe.PM10.mean(), inplace=True)
wanliu_dframe.SO2.fillna(value=wanliu_dframe.SO2.mean(), inplace=True)
wanliu_dframe.NO2.fillna(value=wanliu_dframe.NO2.mean(), inplace=True)
wanliu_dframe.CO.fillna(value=wanliu_dframe.CO.mean(), inplace=True)
wanliu_dframe.O3.fillna(value=wanliu_dframe.O3.mean(), inplace=True)
wanliu_dframe.TEMP.fillna(value=wanliu_dframe.TEMP.mean(), inplace=True)
wanliu_dframe.PRES.fillna(value=wanliu_dframe.PRES.mean(), inplace=True)
wanliu_dframe.DEWP.fillna(value=wanliu_dframe.DEWP.mean(), inplace=True)
wanliu_dframe.RAIN.fillna(value=wanliu_dframe.RAIN.mean(), inplace=True)
wanliu_dframe.wd.fillna(value="NNW", inplace=True)
wanliu_dframe.WSPM.fillna(value=wanliu_dframe.WSPM.mean(), inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2144208782.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wanliu_dframe["PM2.5"].fillna(value=wanliu_dframe["PM2.5"].mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2144208782.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wanliu_dframe.PM10.fillna(value=wanliu_dframe.PM10.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2144208782.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wanliu_dframe.SO2.fillna(value=wanliu_dframe.SO2.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2144208782.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wanliu_dframe.NO2.fillna(value=wanliu_dframe.NO2.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2144208782.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wanliu_dframe.CO.fillna(value=wanliu_dframe.CO.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2144208782.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wanliu_dframe.O3.fillna(value=wanliu_dframe.O3.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2144208782.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wanliu_dframe.TEMP.fillna(value=wanliu_dframe.TEMP.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2144208782.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wanliu_dframe.PRES.fillna(value=wanliu_dframe.PRES.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2144208782.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wanliu_dframe.DEWP.fillna(value=wanliu_dframe.DEWP.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2144208782.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wanliu_dframe.RAIN.fillna(value=wanliu_dframe.RAIN.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2144208782.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wanliu_dframe.wd.fillna(value="NNW", inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\2144208782.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wanliu_dframe.WSPM.fillna(value=wanliu_dframe.WSPM.mean(), inplace=True)

# %% [markdown]
# Memeriksa apakah masih terfapat missing value

# %%
wanliu_dframe.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# Membersihkan Missing Value dari `wanshouxigong_dframe`
#
# Saya mengganti data kualitatif dengan mean() karena dataset mengandung outlier sehingga tidak mempengaruhi parameter statistik yang lain, sementara untuk data kategori mengganti nya dengan yang sering muncul di fiturnya

# %%
wanshouxigong_dframe["PM2.5"].fillna(value=wanshouxigong_dframe["PM2.5"].mean(), inplace=True)
wanshouxigong_dframe.PM10.fillna(value=wanshouxigong_dframe.PM10.mean(), inplace=True)
wanshouxigong_dframe.SO2.fillna(value=wanshouxigong_dframe.SO2.mean(), inplace=True)
wanshouxigong_dframe.NO2.fillna(value=wanshouxigong_dframe.NO2.mean(), inplace=True)
wanshouxigong_dframe.CO.fillna(value=wanshouxigong_dframe.CO.mean(), inplace=True)
wanshouxigong_dframe.O3.fillna(value=wanshouxigong_dframe.O3.mean(), inplace=True)
wanshouxigong_dframe.TEMP.fillna(value=wanshouxigong_dframe.TEMP.mean(), inplace=True)
wanshouxigong_dframe.PRES.fillna(value=wanshouxigong_dframe.PRES.mean(), inplace=True)
wanshouxigong_dframe.DEWP.fillna(value=wanshouxigong_dframe.DEWP.mean(), inplace=True)
wanshouxigong_dframe.RAIN.fillna(value=wanshouxigong_dframe.RAIN.mean(), inplace=True)
wanshouxigong_dframe.wd.fillna(value="NNW", inplace=True)
wanshouxigong_dframe.WSPM.fillna(value=wanshouxigong_dframe.WSPM.mean(), inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\1817704142.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wanshouxigong_dframe["PM2.5"].fillna(value=wanshouxigong_dframe["PM2.5"].mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\1817704142.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wanshouxigong_dframe.PM10.fillna(value=wanshouxigong_dframe.PM10.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\1817704142.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wanshouxigong_dframe.SO2.fillna(value=wanshouxigong_dframe.SO2.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\1817704142.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wanshouxigong_dframe.NO2.fillna(value=wanshouxigong_dframe.NO2.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\1817704142.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wanshouxigong_dframe.CO.fillna(value=wanshouxigong_dframe.CO.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\1817704142.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wanshouxigong_dframe.O3.fillna(value=wanshouxigong_dframe.O3.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\1817704142.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wanshouxigong_dframe.TEMP.fillna(value=wanshouxigong_dframe.TEMP.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\1817704142.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wanshouxigong_dframe.PRES.fillna(value=wanshouxigong_dframe.PRES.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\1817704142.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wanshouxigong_dframe.DEWP.fillna(value=wanshouxigong_dframe.DEWP.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\1817704142.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wanshouxigong_dframe.RAIN.fillna(value=wanshouxigong_dframe.RAIN.mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\1817704142.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wanshouxigong_dframe.wd.fillna(value="NNW", inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18548\1817704142.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wanshouxigong_dframe.WSPM.fillna(value=wanshouxigong_dframe.WSPM.mean(), inplace=True)

# %% [markdown]
# Memeriksa apakah masih terfapat missing value

# %%
wanshouxigong_dframe.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# **Insight:**
# - Mengganti missing value dengan mean() karena di data kita terdapat outlier, sehingga tidak terlalu mempengaruhi hasil
# - wd (wind dirrection) kebanyakan di tiap stasiun sering mengarah ke NNW, hanya stasiun aothizhongxin yang sering mengarah ke NE, maka saya menggantinya dengan nilai yang sering muncul apabila NaN

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore Aotizhongxin

# %% [markdown]
# berdasarkan tahun

# %%
aothizhongxin_year=aothizhongxin_dframe.groupby(by="year").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan bulan

# %%
aothizhongxin_month=aothizhongxin_dframe.groupby(by="month").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan hari

# %%
aothizhongxin_day=aothizhongxin_dframe.groupby(by="day").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan jam

# %%
aothizhongxin_hour=aothizhongxin_dframe.groupby(by="hour").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# ### Explore Changping

# %%
changping_year = changping_dframe.groupby(by="year").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan bulan

# %%
changping_month =changping_dframe.groupby(by="month").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan hari

# %%
changping_day =changping_dframe.groupby(by="day").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan jam

# %%
changping_hour =aothizhongxin_dframe.groupby(by="hour").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# ### Explore Dingling

# %%
dingling_year = dingling_dframe.groupby(by="year").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan bulan

# %%
dingling_month=dingling_dframe.groupby(by="month").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan hari

# %%
dingling_day=dingling_dframe.groupby(by="day").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan jam

# %%
dingling_hour=dingling_dframe.groupby(by="hour").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# ### Explore Dongsi

# %%
dongsi_year=dongsi_dframe.groupby(by="year").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan bulan

# %%
dongsi_month=dongsi_dframe.groupby(by="month").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan hari

# %%
dongsi_day=dongsi_dframe.groupby(by="day").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan jam

# %%
dongsi_hour=dongsi_dframe.groupby(by="hour").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# ### Explore Guanyuan

# %%
guanyuan_year=guanyuan_dframe.groupby(by="year").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan bulan

# %%
guanyuan_month=guanyuan_dframe.groupby(by="month").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan hari

# %%
guanyuan_day=guanyuan_dframe.groupby(by="day").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan jam

# %%
guanyuan_hour=guanyuan_dframe.groupby(by="hour").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# ### Explore Gucheng

# %%
gucheng_year=gucheng_dframe.groupby(by="year").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan bulan

# %%
gucheng_month=gucheng_dframe.groupby(by="month").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan hari

# %%
gucheng_day=gucheng_dframe.groupby(by="day").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan jam

# %%
gucheng_hour=gucheng_dframe.groupby(by="hour").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# ### Explore Huairou

# %%
huairou_year=huairou_dframe.groupby(by="year").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan bulan

# %%
huairou_month=huairou_dframe.groupby(by="month").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan hari

# %%
huairou_day=huairou_dframe.groupby(by="day").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan jam

# %%
huairou_hour=huairou_dframe.groupby(by="hour").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# ### Explore Nongzhanguan

# %%
nongzhanguan_year=nongzhanguan_dframe.groupby(by="year").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan bulan

# %%
nongzhanguan_month=nongzhanguan_dframe.groupby(by="month").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan hari

# %%
nongzhanguan_day=nongzhanguan_dframe.groupby(by="day").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan jam

# %%
nongzhanguan_hour=nongzhanguan_dframe.groupby(by="hour").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# ### Explore Shunyi

# %%
shunyi_year=shunyi_dframe.groupby(by="year").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan bulan

# %%
shunyi_month=shunyi_dframe.groupby(by="month").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan hari

# %%
shunyi_day=shunyi_dframe.groupby(by="day").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan jam

# %%
shunyi_hour=shunyi_dframe.groupby(by="hour").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# ### Explore Tiantan

# %%
tiantan_year=tiantan_dframe.groupby(by="year").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

tiantan_year
# Out:
#           PM2.5               PM10               SO2               NO2         \
#            mean    max        mean    max       mean    max       mean    max
# year
# 2013  83.197686  525.0  108.253070  839.0  18.183159  202.0  53.324068  230.0
# 2014  86.433097  541.0  114.227999  894.0  19.094873  273.0  55.616533  192.0
# 2015  82.600319  671.0  103.048920  887.0  11.883537  227.0  51.934627  218.0
# 2016  74.035380  821.0   97.231196  988.0   8.996355  182.0  50.083009  238.0
# 2017  98.140631  808.0  125.071071  899.0  14.021248  111.0  63.845862  241.0
#
#                CO                  O3              TEMP               PRES  \
#              mean      max       mean    max       mean   max         mean
# year
# 2013  1315.328358   8199.0  54.440069  674.0  15.963657  37.5  1009.828758
# 2014  1314.141234   9300.0  56.976616  369.0  13.881153  41.1  1012.534224
# 2015  1300.419445  10000.0  60.070583  360.0  13.432386  38.8  1012.789625
# 2016  1199.436747  10000.0  55.425489  347.0  13.863387  37.3  1012.824316
# 2017  1712.240207  10000.0  36.041356  104.0   0.775014  15.9  1023.513139
#
#                    DEWP                 RAIN
#          max       mean        max      mean   max
# year
# 2013  1033.3   5.152369  28.800000  0.057979  27.3
# 2014  1035.0   2.604429  25.100000  0.054212  29.0
# 2015  1038.5   2.692271  25.700000  0.072880  36.6
# 2016  1042.0   2.287094  27.300000  0.079753  46.4
# 2017  1036.6 -13.070323   2.447535  0.003605   0.8

# %% [markdown]
# berdasarkan bulan

# %%
tiantan_month=tiantan_dframe.groupby(by="month").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan hari

# %%
tiantan_day=tiantan_dframe.groupby(by="day").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan jam

# %%
tiantan_hour=tiantan_dframe.groupby(by="hour").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# ### Explore Wanliu

# %%
wanliu_year=wanliu_dframe.groupby(by="year").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan bulan

# %%
wanliu_month=wanliu_dframe.groupby(by="month").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan hari

# %%
wanliu_day=wanliu_dframe.groupby(by="day").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan jam

# %%
wanliu_hour=wanliu_dframe.groupby(by="hour").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# ### Explore Wanshouxigong

# %%
wanshouxigong_year=wanshouxigong_dframe.groupby(by="year").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan bulan

# %%
wanshouxigong_month=wanshouxigong_dframe.groupby(by="month").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan hari

# %%
wanshouxigong_day=wanshouxigong_dframe.groupby(by="day").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %% [markdown]
# berdasarkan jam

# %%
wanshouxigong_hour=wanshouxigong_dframe.groupby(by="hour").agg({
    'PM2.5':['mean','max'],
    'PM10':['mean','max'],
    'SO2':['mean','max'],
    'NO2':['mean','max'],
    'CO':['mean','max'],
    'O3':['mean','max'],
    'TEMP':['mean','max'],
    'PRES':['mean','max'],
    'DEWP':['mean','max'],
    'RAIN':['mean','max'],
})

# %%
year_merge = [aothizhongxin_year,changping_year,dingling_year,dongsi_year,guanyuan_year,gucheng_year,huairou_year,nongzhanguan_year,shunyi_year,tiantan_year,wanliu_year,wanshouxigong_year]
month_merge = [aothizhongxin_month,changping_month,dingling_month,dongsi_month,guanyuan_month,gucheng_month,huairou_month,nongzhanguan_month,shunyi_month,tiantan_month,wanliu_month,wanshouxigong_month]
day_merge = [aothizhongxin_day,changping_day,dingling_day,dongsi_day,guanyuan_day,gucheng_day,huairou_day,nongzhanguan_day,shunyi_day,tiantan_day,wanliu_day,wanshouxigong_day]
hour_merge = [aothizhongxin_hour,changping_hour,dingling_hour,dongsi_hour,guanyuan_hour,gucheng_hour,huairou_hour,nongzhanguan_hour,shunyi_hour,tiantan_hour,wanliu_hour,wanshouxigong_hour]

all_year = pd.concat(year_merge).sort_values(by="year")
all_month = pd.concat(month_merge).sort_values(by="month")
all_day = pd.concat(day_merge).sort_values(by="day")
all_hour = pd.concat(hour_merge).sort_values(by="hour")

# %%
all_year
# Out:
#            PM2.5               PM10               SO2               NO2  \
#             mean    max        mean    max       mean    max       mean
# year
# 2013   82.393043  665.0  112.913167  844.0  23.493029  186.0  63.390231
# 2013   77.280065  558.0   94.662433  764.0  15.611348  167.0  41.643163
# 2013   82.140551  512.0  107.772775  999.0  21.833994  189.0  58.274188
# 2013   68.715264  534.0   94.680239  887.0  16.720585  196.0  36.014181
# 2013   86.925760  520.0  105.018146  602.0  23.917829  198.0  57.598815
# 2013   84.033836  510.0  111.315051  961.0  21.811821  219.0  56.126672
# 2013   82.035115  500.0  112.600537  983.0  17.647788  192.0  61.356659
# 2013   64.777450  410.0   78.763031  720.0  14.032211  131.0  29.890448
# 2013   91.572150  560.0  112.282788  829.0  23.648364  172.0  68.536462
# 2013   84.350177  844.0  103.845434  811.0  23.238118  234.0  59.624706
# 2013   72.637567  443.0   91.257159  653.0  19.231476  165.0  41.251464
# 2013   83.197686  525.0  108.253070  839.0  18.183159  202.0  53.324068
# 2014   88.980393  704.0  125.725547  886.0  22.146581  229.0  61.239728
# 2014   84.472716  592.0  110.799902  903.0  17.380501  207.0  45.530298
# 2014   90.333581  584.0  121.389921  948.0  21.097476  197.0  63.742087
# 2014   88.255731  603.0  115.736635  814.0  22.977106  263.0  63.727391
# 2014   89.410417  589.0  130.078648  923.0  24.835117  225.0  75.046117
# 2014   90.185522  809.0  125.105613  907.0  24.437320  208.0  61.958084
# 2014   86.433097  541.0  114.227999  894.0  19.094873  273.0  55.616533
# 2014   79.144216  581.0  106.318472  999.0  20.958338  235.0  45.557611
# 2014   77.011450  528.0   99.889143  993.0  17.410516  315.0  37.240045
# 2014   73.949575  548.0   90.358112  895.0  14.458873  150.0  27.362325
# 2014   87.455485  737.0  116.939118  794.0  23.790487  230.0  55.582203
# 2014   89.139820  770.0  133.565039  862.0  19.728978  500.0  62.032592
# 2015   80.585911  718.0  106.780609  951.0  14.879243  131.0  58.875707
# 2015   70.635958  762.0   89.425734  991.0   8.752582  314.0  28.474908
# 2015   83.631204  741.0  116.261947  941.0  13.375146  248.0  49.902143
# 2015   85.932337  667.0  107.457277  899.0  15.913632  168.0  58.506678
# 2015   82.418859  680.0  106.370617  961.0  14.112923  157.0  54.957516
# 2015   81.250064  689.0   99.689977  999.0  10.540498  160.0  43.226413
# 2015   87.326436  685.0  111.840239  816.0  15.218665  145.0  50.372735
# 2015   64.627529  647.0   85.350134  905.0  11.351143  111.0  26.881813
# 2015   69.672148  500.0   94.153708  992.0  11.841341  310.0  42.799284
# 2015   84.722278  690.0  110.966341  931.0  14.375938  273.0  52.797669
# 2015   82.134578  657.0  112.035381  984.0  14.407922  161.0  60.937350
# 2015   82.600319  671.0  103.048920  887.0  11.883537  227.0  51.934627
# 2016   76.155790  566.0   97.038275  995.0  11.604206  187.0  52.514671
# 2016   72.051435  941.0   87.816802  917.0   9.874575  239.0  43.001996
# 2016   71.561885  957.0   92.986175  919.0  10.708960  282.0  58.515265
# 2016   78.686672  999.0   99.097157  929.0  10.785244  411.0  50.620469
# 2016   77.530704  646.0  110.793668  986.0  10.249753  500.0  50.026417
# 2016   77.228560  639.0  104.738905  906.0  11.544032  277.0  53.572748
# 2016   80.465800  695.0  103.282334  891.0  11.783750  278.0  51.196804
# 2016   60.042212  881.0   80.514580  864.0   7.294931  156.0  25.486036
# 2016   61.778503  882.0   86.422490  933.0   8.277616  257.0  45.548925
# 2016   74.279022  898.0   94.842749  884.0  10.959400  341.0  48.725888
# 2016   61.277062  683.0   82.391200  973.0   6.737304  184.0  27.809710
# 2016   74.035380  821.0   97.231196  988.0   8.996355  182.0  50.083009
# 2017   94.052080  625.0  110.910239  784.0  20.278265  147.0  69.031879
# 2017  101.143993  767.0  126.512784  994.0  20.598720  247.0  62.485696
# 2017   95.421874  762.0  107.090435  951.0  21.125712  157.0  55.476500
# 2017  101.386979  835.0  119.624149  939.0  20.659014  257.0  58.386465
# 2017   74.212586  558.0   92.016072  750.0   9.791628   77.0  38.878500
# 2017   92.691009  664.0  116.965939  917.0  21.291314  293.0  64.996295
# 2017  103.130529  681.0  131.536060  955.0  20.405056  300.0  57.933326
# 2017   68.350216  536.0   78.650888  553.0  13.250526   80.0  34.387971
# 2017   80.012286  662.0   94.364091  775.0  16.417615  111.0  50.947550
# 2017   94.626679  713.0  107.357984  858.0  20.791767  164.0  66.215968
# 2017   98.140631  808.0  125.071071  899.0  14.021248  111.0  63.845862
# 2017  106.866296  823.0  122.609645  952.0  18.670731  189.0  64.460746
#
#                          CO                  O3                  TEMP        \
#            max         mean      max       mean        max       mean   max
# year
# 2013  228.0000  1187.527588   8900.0  50.221417   358.9992  15.497740  37.9
# 2013  204.0000  1230.697973   8700.0  56.589601   351.7164  15.535103  37.8
# 2013  270.0000  1197.387065   7100.0  58.196017   356.0000  15.497740  37.9
# 2013  231.0000  1006.491690   8000.0  61.061847   444.0000  14.660335  36.9
# 2013  258.0000  1335.308738   9400.0  63.489913  1071.0000  15.963657  37.5
# 2013  241.0000  1432.678514   8600.0  55.136895   358.0000  15.854153  38.0
# 2013  240.0000  1299.579201   8000.0  56.117613   325.0000  15.920731  37.7
# 2013  190.3131   852.777553   5100.0  65.187935   382.0000  15.961397  37.9
# 2013  212.0000  1271.923860  10000.0  48.920875   344.0000  15.497740  37.9
# 2013  273.0000  1306.107784   9800.0  56.309899   310.0000  15.963657  37.5
# 2013  199.0000  1052.052075   8100.0  61.399195   429.0000  15.961397  37.9
# 2013  230.0000  1315.328358   8199.0  54.440069   674.0000  15.963657  37.5
# 2014  218.0000  1417.238056   9600.0  56.955014   347.0000  14.292637  40.6
# 2014  204.0000  1166.841285   7600.0  58.348535   333.0000  13.838950  40.6
# 2014  285.0000  1194.545994   8100.0  49.941810   338.0000  13.878128  40.5
# 2014  230.0000  1351.308925   7600.0  55.262818   352.0000  13.878128  40.5
# 2014  264.0000  1365.155011   9600.0  43.146561   342.0000  13.878402  40.5
# 2014  234.0000  1336.974058   9400.0  59.567559   367.0000  13.881153  41.1
# 2014  192.0000  1314.141234   9300.0  56.976616   369.0000  13.881153  41.1
# 2014  195.0000  1195.430974  10000.0  63.080795   413.0000  14.172511  41.4
# 2014  219.0000  1062.548587   6700.0  67.009783   391.0000  12.802556  40.3
# 2014  174.0000   877.656411   6900.0  72.515434   411.0000  14.172511  41.4
# 2014  236.0000  1367.693735   7700.0  57.245953   320.0000  13.881153  41.1
# 2014  224.0000  1420.910931   8800.0  58.803854   374.0000  14.432279  41.6
# 2015  225.0000  1331.416244  10000.0  52.015366   364.0000  13.355740  39.0
# 2015  162.0000  1041.465967  10000.0  60.177105   413.0000  12.455504  39.0
# 2015  216.0000  1324.927073   9900.0  60.666683   450.0000  14.061955  39.3
# 2015  265.0000  1377.260118  10000.0  61.217834   364.0000  13.432386  38.8
# 2015  239.0000  1314.617354  10000.0  56.758876   352.0000  13.478428  38.8
# 2015  238.0000  1180.508108  10000.0  52.165830   340.0000  13.293471  39.0
# 2015  256.0000  1335.668400  10000.0  55.796035   308.0000  13.432386  38.8
# 2015  186.0000   966.453378   9400.0  70.953036   432.0000  13.611578  39.2
# 2015  199.0000  1161.859538   9900.0  57.912187   359.0000  13.611578  39.2
# 2015  211.0000  1356.013357   9800.0  58.885940   355.0000  13.564731  38.8
# 2015  290.0000  1395.649081  10000.0  63.748528   423.0000  13.478428  38.8
# 2015  218.0000  1300.419445  10000.0  60.070583   360.0000  13.432386  38.8
# 2016  206.0000  1214.198103   9400.0  60.179288   390.0000  13.863387  37.3
# 2016  195.0000  1086.617368   9900.0  56.021769   339.0000  13.381310  36.6
# 2016  253.0000  1233.515469  10000.0  53.501285   318.0000  13.404872  38.2
# 2016  235.0000  1234.344447   9800.0  57.268323   340.0000  13.863477  37.3
# 2016  229.0000  1172.853995  10000.0  59.527469   348.0000  13.539710  37.2
# 2016  225.0000  1174.867143   9300.0  54.945471   335.0000  13.863318  37.3
# 2016  210.0000  1243.028459   9900.0  56.145993   342.0000  13.863387  37.3
# 2016  205.0000   874.441321   9400.0  67.357060   500.0000  13.491736  38.1
# 2016  226.0000  1123.589296  10000.0  53.904720   327.0000  13.491736  38.1
# 2016  218.0000  1196.488727  10000.0  61.914457   350.0000  13.863318  37.3
# 2016  189.0000   930.424207   9300.0  53.385516   356.0000  12.405476  36.5
# 2016  238.0000  1199.436747  10000.0  55.425489   347.0000  13.863387  37.3
# 2017  249.0000  1739.857815  10000.0  35.915060   102.0000   0.518962  16.2
# 2017  276.0000  1782.372249  10000.0  29.261502    74.0000   0.481308  15.5
# 2017  258.0000  1749.532339   9600.0  42.220353   173.0000   0.087937  15.4
# 2017  194.0000  1696.858939   9700.0  36.882272    94.0000   0.775014  15.9
# 2017  174.0000  1312.968830   9800.0  46.723178   119.0000  -1.065963  15.8
# 2017  207.0000  1489.765711   9800.0  45.942674   415.0000   0.774339  15.9
# 2017  192.0000  1575.439513   9500.0  39.780815   500.0000   0.775014  15.9
# 2017  190.0000  1151.824317  10000.0  53.948925   104.0000   0.543273  15.6
# 2017  203.0000  1524.400162   9900.0  33.400410   148.0000   0.543273  15.6
# 2017  217.0000  1668.531169   9900.0  47.573536   133.0000   0.774339  15.9
# 2017  241.0000  1712.240207  10000.0  36.041356   104.0000   0.775014  15.9
# 2017  251.0000  1690.520016   9300.0  34.539743    88.0000   0.775892  15.9
#
#              PRES               DEWP                 RAIN
#              mean     max       mean        max      mean   max
# year
# 2013  1008.200408  1031.3   6.465400  28.500000  0.071582  72.5
# 2013  1010.492062  1033.8   5.544049  27.400000  0.064828  31.2
# 2013  1008.200408  1031.3   6.465400  28.500000  0.071582  72.5
# 2013  1004.994363  1028.0   5.123897  29.100000  0.072331  45.9
# 2013  1009.828758  1033.3   5.152369  28.800000  0.057979  27.3
# 2013  1007.212786  1030.5   5.750027  28.500000  0.065182  23.8
# 2013  1006.111684  1029.4   5.461216  27.400000  0.070003  36.6
# 2013  1004.957489  1027.9   4.471882  27.200000  0.066068  25.3
# 2013  1008.200408  1031.3   6.465400  28.500000  0.071582  72.5
# 2013  1009.828758  1033.3   5.152369  28.800000  0.057979  27.3
# 2013  1004.957489  1027.9   4.471882  27.200000  0.066068  25.3
# 2013  1009.828758  1033.3   5.152369  28.800000  0.057979  27.3
# 2014  1010.961130  1037.0   3.012842  25.400000  0.049064  22.4
# 2014  1012.507317  1035.9   2.437797  24.900000  0.050890  37.3
# 2014  1011.318082  1036.0   4.162203  26.600000  0.056610  40.7
# 2014  1011.318082  1036.0   4.162203  26.600000  0.056610  40.7
# 2014  1011.311313  1036.0   4.166895  26.600000  0.056575  40.7
# 2014  1012.534224  1035.0   2.604429  25.100000  0.054212  29.0
# 2014  1012.534224  1035.0   2.604429  25.100000  0.054212  29.0
# 2014  1008.153664  1032.0   1.037260  24.400000  0.037888  21.6
# 2014  1007.490182  1032.0   2.127986  25.300000  0.052485  45.9
# 2014  1008.153664  1032.0   1.037260  24.400000  0.037888  21.6
# 2014  1012.534224  1035.0   2.604429  25.100000  0.054212  29.0
# 2014  1008.879840  1032.0   2.946325  26.800000  0.036895  39.0
# 2015  1011.258299  1036.7   3.045483  25.800000  0.072470  47.7
# 2015  1007.861744  1033.4   2.516335  26.200000  0.081036  30.9
# 2015  1009.129860  1035.0   3.176972  26.200000  0.080876  41.9
# 2015  1012.789625  1038.5   2.692271  25.700000  0.072880  36.6
# 2015  1012.568426  1038.5   2.736284  25.700000  0.072687  36.6
# 2015  1013.494733  1039.4   2.736352  25.400000  0.076509  30.9
# 2015  1012.789625  1038.5   2.692271  25.700000  0.072880  36.6
# 2015  1007.850727  1033.1   1.844610  24.600000  0.082552  52.1
# 2015  1007.850727  1033.1   1.844610  24.600000  0.082552  52.1
# 2015  1012.412663  1038.5   2.822615  25.700000  0.073192  36.6
# 2015  1012.568426  1038.5   2.736284  25.700000  0.072687  36.6
# 2015  1012.789625  1038.5   2.692271  25.700000  0.072880  36.6
# 2016  1012.824316  1042.0   2.287094  27.300000  0.079753  46.4
# 2016  1013.539514  1042.8   2.164529  27.500000  0.062134  19.5
# 2016  1011.311992  1040.3   2.525497  27.000000  0.083388  28.9
# 2016  1012.823491  1042.0   2.287301  27.300000  0.079753  46.4
# 2016  1009.152238  1038.1   2.005143  26.800000  0.080789  30.4
# 2016  1012.823758  1042.0   2.287632  27.300000  0.079755  46.4
# 2016  1012.824316  1042.0   2.287094  27.300000  0.079753  46.4
# 2016  1007.920728  1036.5   1.646874  26.900000  0.065326  22.7
# 2016  1007.920728  1036.5   1.646874  26.900000  0.065326  22.7
# 2016  1012.823758  1042.0   2.287632  27.300000  0.079755  46.4
# 2016  1007.907753  1036.5   2.217107  27.300000  0.076841  36.1
# 2016  1012.824316  1042.0   2.287094  27.300000  0.079753  46.4
# 2017  1022.475887  1035.0 -12.928438   3.266588  0.003496   1.0
# 2017  1018.755906  1032.6 -14.002751   2.610442  0.003209   1.3
# 2017  1024.181534  1037.6 -13.149894   2.465036  0.003044   1.1
# 2017  1023.513139  1036.6 -13.070323   2.447535  0.003605   0.8
# 2017  1018.229525  1031.4 -13.625901   2.238619  0.004531   1.0
# 2017  1023.507697  1036.6 -13.065075   3.123062  0.003631   0.8
# 2017  1023.513139  1036.6 -13.070323   2.447535  0.003605   0.8
# 2017  1018.308218  1031.2 -13.957718   1.505495  0.001839   0.6
# 2017  1018.308218  1031.2 -13.957718   1.505495  0.001839   0.6
# 2017  1023.507697  1036.6 -13.065075   3.123062  0.003631   0.8
# 2017  1023.513139  1036.6 -13.070323   2.447535  0.003605   0.8
# 2017  1023.505094  1036.6 -13.068304   2.707442  0.003607   0.8

# %%
all_month
# Out:
#             PM2.5               PM10               SO2               NO2  \
#              mean    max        mean    max       mean    max       mean
# month
# 1       92.732675  713.0  113.883041  858.0  34.788355  197.0  65.989555
# 1       97.711809  625.0  120.743989  923.0  35.249198  221.0  75.606189
# 1       98.300374  808.0  119.430200  899.0  27.190813  200.0  67.953975
# 1       95.113751  762.0  107.533581  951.0  27.032717  176.0  54.495390
# 1      101.711205  835.0  122.306065  939.0  36.707924  212.0  67.693163
# ...           ...    ...         ...    ...        ...    ...        ...
# 12      78.618786  647.0   91.295634  771.0  20.168824  150.0  43.733202
# 12      87.356214  596.0  110.564993  770.0  25.520038  165.0  61.010540
# 12     107.785850  657.0  130.524228  675.0  26.116366  186.0  73.100737
# 12     110.575476  718.0  132.097689  718.0  29.221090  172.0  76.756367
# 12     121.068159  690.0  145.029727  690.0  29.701324  219.0  73.474266
#
#                        CO                  O3             TEMP             \
#          max         mean      max       mean    max      mean        max
# month
# 1      217.0  1946.694215   9900.0  27.507043  133.0 -1.575370  14.000000
# 1      249.0  2236.129887  10000.0  25.415856   93.0 -1.529930  14.000000
# 1      241.0  1895.806538  10000.0  26.219658   93.0 -1.719811  13.671490
# 1      258.0  1735.838599   9600.0  30.727713  173.0 -2.006092  13.387969
# 1      208.0  1902.691114   9700.0  28.004488   95.0 -1.719811  13.671490
# ...      ...          ...      ...        ...    ...       ...        ...
# 12     205.0  1443.140722   9400.0  31.885424  500.0  0.100067  14.200000
# 12     226.0  1964.344325  10000.0  20.715509   72.0  0.100067  14.200000
# 12     218.0  2176.014566  10000.0  25.184957   82.0 -0.133031  14.800000
# 12     234.0  2262.642863  10000.0  18.765227  193.0 -0.247480  14.800000
# 12     235.0  2404.868121   9800.0  19.458778   76.0  0.011559  15.000000
#
#               PRES               DEWP                RAIN
#               mean     max       mean       max      mean  max
# month
# 1      1023.201382  1042.0 -14.263146  3.123062  0.000608  0.2
# 1      1022.616169  1040.3 -14.219994  3.266588  0.000410  0.2
# 1      1024.026855  1042.0 -14.550548  2.447535  0.000594  0.2
# 1      1024.745901  1042.8 -14.588975  2.465036  0.000791  0.5
# 1      1024.026855  1042.0 -14.550548  2.447535  0.000594  0.2
# ...            ...     ...        ...       ...       ...  ...
# 12     1018.955914  1032.0 -12.869523  1.500000  0.001042  0.7
# 12     1018.955914  1032.0 -12.869523  1.500000  0.001042  0.7
# 12     1022.891868  1036.3 -11.002117  2.200000  0.000706  0.6
# 12     1022.081216  1035.0 -11.244153  1.300000  0.001411  0.7
# 12     1023.147614  1037.0 -11.490860  2.200000  0.000706  0.6
#
# [144 rows x 20 columns]

# %%
all_day
# Out:
#          PM2.5               PM10               SO2               NO2         \
#           mean    max        mean    max       mean    max       mean    max
# day
# 1    90.470927  607.0  113.925474  628.0  15.053873   92.0  59.120315  217.0
# 1    88.542078  641.0  111.728615  660.0  12.763146   88.0  52.208040  194.0
# 1    96.094810  741.0  124.849356  800.0  12.650112   75.0  55.301293  208.0
# 1    94.796377  680.0  116.194101  710.0  16.233098   94.0  53.291207  186.0
# 1    93.132984  718.0  115.479156  785.0  15.383671   75.0  65.789450  229.0
# ..         ...    ...         ...    ...        ...    ...        ...    ...
# 31   67.346007  293.0   94.021031  450.0  12.873456   60.0  28.495249  162.0
# 31   73.233328  300.0  105.317489  407.0  16.050974   97.0  43.036600  164.0
# 31   87.633581  472.0  122.388466  725.0  17.794526   93.0  58.292479  218.0
# 31   86.492223  475.0  120.247951  529.0  18.174336   99.0  64.027492  203.0
# 31   92.490050  556.0  122.851207  886.0  17.757721  245.0  53.669383  220.0
#
#               CO                  O3              TEMP               PRES  \
#             mean      max       mean    max       mean   max         mean
# day
# 1    1254.240865  10000.0  53.388991  302.0  13.383681  32.5  1011.153646
# 1    1334.312089   8900.0  53.691514  300.0  13.501736  32.2  1011.940625
# 1    1392.739852   9700.0  56.037682  310.0  13.677431  34.1  1008.332292
# 1    1450.549464  10000.0  55.360164  267.0  13.501736  32.2  1011.940625
# 1    1355.466478   9800.0  47.652739  311.0  13.156019  33.8  1010.394850
# ..           ...      ...        ...    ...        ...   ...          ...
# 31    949.889936   4600.0  70.540716  343.0  13.636884  33.9  1007.777619
# 31   1143.786040   9100.0  61.492188  321.0  13.636884  33.9  1007.777619
# 31   1248.014328   6000.0  58.237660  276.0  13.438690  34.1  1012.168601
# 31   1265.820647   7200.0  50.691834  292.0  13.212798  35.1  1011.388690
# 31   1344.660916   7000.0  59.630634  301.0  13.636310  34.1  1011.785714
#
#                  DEWP            RAIN
#         max      mean   max      mean   max
# day
# 1    1036.0  3.217448  25.7  0.109896  21.0
# 1    1036.0  2.664757  24.8  0.140017  11.8
# 1    1032.0  2.692795  25.2  0.097135  21.0
# 1    1036.0  2.664757  24.8  0.140017  11.8
# 1    1034.2  3.306076  25.7  0.114844  21.0
# ..      ...       ...   ...       ...   ...
# 31   1033.0  2.095246  23.6  0.092649  25.3
# 31   1033.0  2.095246  23.6  0.092649  25.3
# 31   1036.4  3.283482  26.4  0.155208  12.9
# 31   1036.0  3.623958  26.4  0.104762  12.9
# 31   1036.4  2.929167  25.2  0.128869  22.4
#
# [372 rows x 20 columns]

# %%
all_hour
# Out:
#           PM2.5               PM10               SO2               NO2         \
#            mean    max        mean    max       mean    max       mean    max
# hour
# 0     92.099235  584.0  124.350027  844.0  18.150487  197.0  71.550544  253.0
# 0     94.028921  809.0  121.212110  907.0  19.030570  226.0  69.192207  246.0
# 0     91.064842  603.0  120.067985  813.0  18.031951  186.0  65.862281  222.0
# 0     93.589195  623.0  117.334413  912.0  13.775560  163.0  53.992534  188.0
# 0     96.944408  679.0  124.497185  819.0  19.009088  196.0  63.262379  241.0
# ...         ...    ...         ...    ...        ...    ...        ...    ...
# 23    67.236684  568.0   83.166881  842.0   9.616118  104.0  27.122256  172.0
# 23    91.677469  565.0  125.403798  609.0  17.905197  185.0  72.178340  269.0
# 23    91.677469  565.0  125.403798  609.0  17.905197  185.0  72.178340  269.0
# 23    93.028729  568.0  128.829625  636.0  18.214037  215.0  78.218488  252.0
# 23    94.594715  704.0  126.988995  836.0  16.661213  159.0  66.225139  206.0
#
#                CO                  O3               TEMP               PRES  \
#              mean      max       mean     max       mean   max         mean
# hour
# 0     1433.198032   9700.0  39.501768   200.0  11.373715  32.8  1012.252040
# 0     1485.715304   9800.0  42.570553   195.0  11.609709  32.8  1012.964292
# 0     1393.474828  10000.0  41.985790   177.0  11.373715  32.8  1012.252040
# 0     1422.210239  10000.0  39.209720   204.0  11.094672  31.7  1013.492228
# 0     1478.929208   9400.0  43.674057  1071.0  11.609709  32.8  1012.964292
# ...           ...      ...        ...     ...        ...   ...          ...
# 23     933.161203   8700.0  61.507647   403.0  11.885200  32.8  1008.233123
# 23    1411.244116  10000.0  44.038228   219.0  11.900862  33.2  1012.262854
# 23    1411.244116  10000.0  44.038228   219.0  11.900862  33.2  1012.262854
# 23    1467.273044   9100.0  35.760609   170.0  11.477963  32.2  1011.518878
# 23    1525.430374   9200.0  42.411206   202.0  12.097098  33.2  1011.910880
#
#                   DEWP            RAIN
#          max      mean   max      mean   max
# hour
# 0     1040.8  3.826504  27.6  0.075542  23.3
# 0     1040.8  3.180183  27.9  0.080126  15.5
# 0     1040.8  3.826504  27.6  0.075542  23.3
# 0     1041.5  3.260825  26.7  0.060138  14.7
# 0     1040.8  3.180183  27.9  0.080126  15.5
# ...      ...       ...   ...       ...   ...
# 23    1035.6  1.814651  26.9  0.085804  18.4
# 23    1041.2  3.804123  27.8  0.098403  23.6
# 23    1041.2  3.804123  27.8  0.098403  23.6
# 23    1039.3  4.009902  27.8  0.106549  23.6
# 23    1041.2  3.426631  27.3  0.092378  18.1
#
# [288 rows x 20 columns]

# %% [markdown]
# **Insight:**
# - Memisahkah kategori berdasarka tahun,bulan,hari, dan jam
# - Dapat melihat parameter statisktik dari tahun,bulan,hari,jam

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana konsentrasi PM10 dan PM2.5 dalam diagram tahun dan bulan pada tiap kota?

# %%
sns.set_theme(style="darkgrid")
sns.set_palette("Set2")
fig, ax = plt.subplots(figsize=(10, 6))
year = aothizhongxin_year.index
ax.plot(year, aothizhongxin_year['PM2.5']['mean'], label='PM2.5 Mean', marker='o', linewidth=2)
ax.plot(year, aothizhongxin_year['PM2.5']['max'], label='PM2.5 Max', marker='x', linewidth=2)
ax.plot(year, aothizhongxin_year['PM10']['mean'], label='PM10 Mean', marker='o', linewidth=2)
ax.plot(year, aothizhongxin_year['PM10']['max'], label='PM10 Max', marker='x', linewidth=2)
ax.set_title('Aothizhongxin Yearly PM2.5 and PM10 Levels', fontsize=18, weight='bold')
ax.set_xlabel('Year', fontsize=14)
ax.set_ylabel('Concentration (µg/m³)', fontsize=14)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)
ax.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.set_palette("Set2")
fig, ax = plt.subplots(figsize=(10, 6))
months = aothizhongxin_month.index
ax.plot(months, aothizhongxin_month['PM2.5']['mean'], label='PM2.5 Mean', marker='o', linewidth=2)
ax.plot(months, aothizhongxin_month['PM2.5']['max'], label='PM2.5 Max', marker='x', linewidth=2)
ax.plot(months, aothizhongxin_month['PM10']['mean'], label='PM10 Mean', marker='o', linewidth=2)
ax.plot(months, aothizhongxin_month['PM10']['max'], label='PM10 Max', marker='x', linewidth=2)
ax.set_title('Aothizhongxin Monthly PM2.5 and PM10 Levels', fontsize=18, weight='bold')
ax.set_xlabel('Month', fontsize=14)
ax.set_ylabel('Concentration (µg/m³)', fontsize=14)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)
ax.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.set_palette("Set2")
fig, ax = plt.subplots(figsize=(10, 6))
year = changping_year.index
ax.plot(year, changping_year['PM2.5']['mean'], label='PM2.5 Mean', marker='o', linewidth=2)
ax.plot(year, changping_year['PM2.5']['max'], label='PM2.5 Max', marker='x', linewidth=2)
ax.plot(year, changping_year['PM10']['mean'], label='PM10 Mean', marker='o', linewidth=2)
ax.plot(year, changping_year['PM10']['max'], label='PM10 Max', marker='x', linewidth=2)
ax.set_title('changping Yearly PM2.5 and PM10 Levels', fontsize=18, weight='bold')
ax.set_xlabel('Year', fontsize=14)
ax.set_ylabel('Concentration (µg/m³)', fontsize=14)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)
ax.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.set_palette("Set2")
fig, ax = plt.subplots(figsize=(10, 6))
months = changping_month.index
ax.plot(months, changping_month['PM2.5']['mean'], label='PM2.5 Mean', marker='o', linewidth=2)
ax.plot(months, changping_month['PM2.5']['max'], label='PM2.5 Max', marker='x', linewidth=2)
ax.plot(months, changping_month['PM10']['mean'], label='PM10 Mean', marker='o', linewidth=2)
ax.plot(months, changping_month['PM10']['max'], label='PM10 Max', marker='x', linewidth=2)
ax.set_title('changping Monthly PM2.5 and PM10 Levels', fontsize=18, weight='bold')
ax.set_xlabel('Month', fontsize=14)
ax.set_ylabel('Concentration (µg/m³)', fontsize=14)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)
ax.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.set_palette("Set2")
fig, ax = plt.subplots(figsize=(10, 6))
year = dingling_year.index
ax.plot(year, dingling_year['PM2.5']['mean'], label='PM2.5 Mean', marker='o', linewidth=2)
ax.plot(year, dingling_year['PM2.5']['max'], label='PM2.5 Max', marker='x', linewidth=2)
ax.plot(year, dingling_year['PM10']['mean'], label='PM10 Mean', marker='o', linewidth=2)
ax.plot(year, dingling_year['PM10']['max'], label='PM10 Max', marker='x', linewidth=2)
ax.set_title('dingling Yearly PM2.5 and PM10 Levels', fontsize=18, weight='bold')
ax.set_xlabel('Year', fontsize=14)
ax.set_ylabel('Concentration (µg/m³)', fontsize=14)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)
ax.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.set_palette("Set2")
fig, ax = plt.subplots(figsize=(10, 6))
months = dingling_month.index
ax.plot(months, dingling_month['PM2.5']['mean'], label='PM2.5 Mean', marker='o', linewidth=2)
ax.plot(months, dingling_month['PM2.5']['max'], label='PM2.5 Max', marker='x', linewidth=2)
ax.plot(months, dingling_month['PM10']['mean'], label='PM10 Mean', marker='o', linewidth=2)
ax.plot(months, dingling_month['PM10']['max'], label='PM10 Max', marker='x', linewidth=2)
ax.set_title('dingling Monthly PM2.5 and PM10 Levels', fontsize=18, weight='bold')
ax.set_xlabel('Month', fontsize=14)
ax.set_ylabel('Concentration (µg/m³)', fontsize=14)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)
ax.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.set_palette("Set2")
fig, ax = plt.subplots(figsize=(10, 6))
year = dongsi_year.index
ax.plot(year, dongsi_year['PM2.5']['mean'], label='PM2.5 Mean', marker='o', linewidth=2)
ax.plot(year, dongsi_year['PM2.5']['max'], label='PM2.5 Max', marker='x', linewidth=2)
ax.plot(year, dongsi_year['PM10']['mean'], label='PM10 Mean', marker='o', linewidth=2)
ax.plot(year, dongsi_year['PM10']['max'], label='PM10 Max', marker='x', linewidth=2)
ax.set_title('dongsi Yearly PM2.5 and PM10 Levels', fontsize=18, weight='bold')
ax.set_xlabel('Year', fontsize=14)
ax.set_ylabel('Concentration (µg/m³)', fontsize=14)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)
ax.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.set_palette("Set2")
fig, ax = plt.subplots(figsize=(10, 6))
months = dongsi_month.index
ax.plot(months, dongsi_month['PM2.5']['mean'], label='PM2.5 Mean', marker='o', linewidth=2)
ax.plot(months, dongsi_month['PM2.5']['max'], label='PM2.5 Max', marker='x', linewidth=2)
ax.plot(months, dongsi_month['PM10']['mean'], label='PM10 Mean', marker='o', linewidth=2)
ax.plot(months, dongsi_month['PM10']['max'], label='PM10 Max', marker='x', linewidth=2)
ax.set_title('dongsi Monthly PM2.5 and PM10 Levels', fontsize=18, weight='bold')
ax.set_xlabel('Month', fontsize=14)
ax.set_ylabel('Concentration (µg/m³)', fontsize=14)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)
ax.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.set_palette("Set2")
fig, ax = plt.subplots(figsize=(10, 6))
year = guanyuan_year.index
ax.plot(year, guanyuan_year['PM2.5']['mean'], label='PM2.5 Mean', marker='o', linewidth=2)
ax.plot(year, guanyuan_year['PM2.5']['max'], label='PM2.5 Max', marker='x', linewidth=2)
ax.plot(year, guanyuan_year['PM10']['mean'], label='PM10 Mean', marker='o', linewidth=2)
ax.plot(year, guanyuan_year['PM10']['max'], label='PM10 Max', marker='x', linewidth=2)
ax.set_title('guanyuan Yearly PM2.5 and PM10 Levels', fontsize=18, weight='bold')
ax.set_xlabel('Year', fontsize=14)
ax.set_ylabel('Concentration (µg/m³)', fontsize=14)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)
ax.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.set_palette("Set2")
fig, ax = plt.subplots(figsize=(10, 6))
months = guanyuan_month.index
ax.plot(months, guanyuan_month['PM2.5']['mean'], label='PM2.5 Mean', marker='o', linewidth=2)
ax.plot(months, guanyuan_month['PM2.5']['max'], label='PM2.5 Max', marker='x', linewidth=2)
ax.plot(months, guanyuan_month['PM10']['mean'], label='PM10 Mean', marker='o', linewidth=2)
ax.plot(months, guanyuan_month['PM10']['max'], label='PM10 Max', marker='x', linewidth=2)
ax.set_title('guanyuan Monthly PM2.5 and PM10 Levels', fontsize=18, weight='bold')
ax.set_xlabel('Month', fontsize=14)
ax.set_ylabel('Concentration (µg/m³)', fontsize=14)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)
ax.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.set_palette("Set2")
fig, ax = plt.subplots(figsize=(10, 6))
year = gucheng_year.index
ax.plot(year, gucheng_year['PM2.5']['mean'], label='PM2.5 Mean', marker='o', linewidth=2)
ax.plot(year, gucheng_year['PM2.5']['max'], label='PM2.5 Max', marker='x', linewidth=2)
ax.plot(year, gucheng_year['PM10']['mean'], label='PM10 Mean', marker='o', linewidth=2)
ax.plot(year, gucheng_year['PM10']['max'], label='PM10 Max', marker='x', linewidth=2)
ax.set_title('gucheng Yearly PM2.5 and PM10 Levels', fontsize=18, weight='bold')
ax.set_xlabel('Year', fontsize=14)
ax.set_ylabel('Concentration (µg/m³)', fontsize=14)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)
ax.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.set_palette("Set2")
fig, ax = plt.subplots(figsize=(10, 6))
months = gucheng_month.index
ax.plot(months, gucheng_month['PM2.5']['mean'], label='PM2.5 Mean', marker='o', linewidth=2)
ax.plot(months, gucheng_month['PM2.5']['max'], label='PM2.5 Max', marker='x', linewidth=2)
ax.plot(months, gucheng_month['PM10']['mean'], label='PM10 Mean', marker='o', linewidth=2)
ax.plot(months, gucheng_month['PM10']['max'], label='PM10 Max', marker='x', linewidth=2)
ax.set_title('gucheng Monthly PM2.5 and PM10 Levels', fontsize=18, weight='bold')
ax.set_xlabel('Month', fontsize=14)
ax.set_ylabel('Concentration (µg/m³)', fontsize=14)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)
ax.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.set_palette("Set2")
fig, ax = plt.subplots(figsize=(10, 6))
year = huairou_year.index
ax.plot(year, huairou_year['PM2.5']['mean'], label='PM2.5 Mean', marker='o', linewidth=2)
ax.plot(year, huairou_year['PM2.5']['max'], label='PM2.5 Max', marker='x', linewidth=2)
ax.plot(year, huairou_year['PM10']['mean'], label='PM10 Mean', marker='o', linewidth=2)
ax.plot(year, huairou_year['PM10']['max'], label='PM10 Max', marker='x', linewidth=2)
ax.set_title('huairou Yearly PM2.5 and PM10 Levels', fontsize=18, weight='bold')
ax.set_xlabel('Year', fontsize=14)
ax.set_ylabel('Concentration (µg/m³)', fontsize=14)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)
ax.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.set_palette("Set2")
fig, ax = plt.subplots(figsize=(10, 6))
months = huairou_month.index
ax.plot(months, huairou_month['PM2.5']['mean'], label='PM2.5 Mean', marker='o', linewidth=2)
ax.plot(months, huairou_month['PM2.5']['max'], label='PM2.5 Max', marker='x', linewidth=2)
ax.plot(months, huairou_month['PM10']['mean'], label='PM10 Mean', marker='o', linewidth=2)
ax.plot(months, huairou_month['PM10']['max'], label='PM10 Max', marker='x', linewidth=2)
ax.set_title('huairou Monthly PM2.5 and PM10 Levels', fontsize=18, weight='bold')
ax.set_xlabel('Month', fontsize=14)
ax.set_ylabel('Concentration (µg/m³)', fontsize=14)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)
ax.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.set_palette("Set2")
fig, ax = plt.subplots(figsize=(10, 6))
year = nongzhanguan_year.index
ax.plot(year, nongzhanguan_year['PM2.5']['mean'], label='PM2.5 Mean', marker='o', linewidth=2)
ax.plot(year, nongzhanguan_year['PM2.5']['max'], label='PM2.5 Max', marker='x', linewidth=2)
ax.plot(year, nongzhanguan_year['PM10']['mean'], label='PM10 Mean', marker='o', linewidth=2)
ax.plot(year, nongzhanguan_year['PM10']['max'], label='PM10 Max', marker='x', linewidth=2)
ax.set_title('nongzhanguan Yearly PM2.5 and PM10 Levels', fontsize=18, weight='bold')
ax.set_xlabel('Year', fontsize=14)
ax.set_ylabel('Concentration (µg/m³)', fontsize=14)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)
ax.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.set_palette("Set2")
fig, ax = plt.subplots(figsize=(10, 6))
months = nongzhanguan_month.index
ax.plot(months, nongzhanguan_month['PM2.5']['mean'], label='PM2.5 Mean', marker='o', linewidth=2)
ax.plot(months, nongzhanguan_month['PM2.5']['max'], label='PM2.5 Max', marker='x', linewidth=2)
ax.plot(months, nongzhanguan_month['PM10']['mean'], label='PM10 Mean', marker='o', linewidth=2)
ax.plot(months, nongzhanguan_month['PM10']['max'], label='PM10 Max', marker='x', linewidth=2)
ax.set_title('nongzhanguan Monthly PM2.5 and PM10 Levels', fontsize=18, weight='bold')
ax.set_xlabel('Month', fontsize=14)
ax.set_ylabel('Concentration (µg/m³)', fontsize=14)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)
ax.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.set_palette("Set2")
fig, ax = plt.subplots(figsize=(10, 6))
year = shunyi_year.index
ax.plot(year, shunyi_year['PM2.5']['mean'], label='PM2.5 Mean', marker='o', linewidth=2)
ax.plot(year, shunyi_year['PM2.5']['max'], label='PM2.5 Max', marker='x', linewidth=2)
ax.plot(year, shunyi_year['PM10']['mean'], label='PM10 Mean', marker='o', linewidth=2)
ax.plot(year, shunyi_year['PM10']['max'], label='PM10 Max', marker='x', linewidth=2)
ax.set_title('shunyi Yearly PM2.5 and PM10 Levels', fontsize=18, weight='bold')
ax.set_xlabel('Year', fontsize=14)
ax.set_ylabel('Concentration (µg/m³)', fontsize=14)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)
ax.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.set_palette("Set2")
fig, ax = plt.subplots(figsize=(10, 6))
months = shunyi_month.index
ax.plot(months, shunyi_month['PM2.5']['mean'], label='PM2.5 Mean', marker='o', linewidth=2)
ax.plot(months, shunyi_month['PM2.5']['max'], label='PM2.5 Max', marker='x', linewidth=2)
ax.plot(months, shunyi_month['PM10']['mean'], label='PM10 Mean', marker='o', linewidth=2)
ax.plot(months, shunyi_month['PM10']['max'], label='PM10 Max', marker='x', linewidth=2)
ax.set_title('shunyi Monthly PM2.5 and PM10 Levels', fontsize=18, weight='bold')
ax.set_xlabel('Month', fontsize=14)
ax.set_ylabel('Concentration (µg/m³)', fontsize=14)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)
ax.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.set_palette("Set2")
fig, ax = plt.subplots(figsize=(10, 6))
year = tiantan_year.index
ax.plot(year, tiantan_year['PM2.5']['mean'], label='PM2.5 Mean', marker='o', linewidth=2)
ax.plot(year, tiantan_year['PM2.5']['max'], label='PM2.5 Max', marker='x', linewidth=2)
ax.plot(year, tiantan_year['PM10']['mean'], label='PM10 Mean', marker='o', linewidth=2)
ax.plot(year, tiantan_year['PM10']['max'], label='PM10 Max', marker='x', linewidth=2)
ax.set_title('tiantan Yearly PM2.5 and PM10 Levels', fontsize=18, weight='bold')
ax.set_xlabel('Year', fontsize=14)
ax.set_ylabel('Concentration (µg/m³)', fontsize=14)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)
ax.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.set_palette("Set2")
fig, ax = plt.subplots(figsize=(10, 6))
months = tiantan_month.index
ax.plot(months, tiantan_month['PM2.5']['mean'], label='PM2.5 Mean', marker='o', linewidth=2)
ax.plot(months, tiantan_month['PM2.5']['max'], label='PM2.5 Max', marker='x', linewidth=2)
ax.plot(months, tiantan_month['PM10']['mean'], label='PM10 Mean', marker='o', linewidth=2)
ax.plot(months, tiantan_month['PM10']['max'], label='PM10 Max', marker='x', linewidth=2)
ax.set_title('tiantan Monthly PM2.5 and PM10 Levels', fontsize=18, weight='bold')
ax.set_xlabel('Month', fontsize=14)
ax.set_ylabel('Concentration (µg/m³)', fontsize=14)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)
ax.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.set_palette("Set2")
fig, ax = plt.subplots(figsize=(10, 6))
year = wanliu_year.index
ax.plot(year, wanliu_year['PM2.5']['mean'], label='PM2.5 Mean', marker='o', linewidth=2)
ax.plot(year, wanliu_year['PM2.5']['max'], label='PM2.5 Max', marker='x', linewidth=2)
ax.plot(year, wanliu_year['PM10']['mean'], label='PM10 Mean', marker='o', linewidth=2)
ax.plot(year, wanliu_year['PM10']['max'], label='PM10 Max', marker='x', linewidth=2)
ax.set_title('wanliu Yearly PM2.5 and PM10 Levels', fontsize=18, weight='bold')
ax.set_xlabel('Year', fontsize=14)
ax.set_ylabel('Concentration (µg/m³)', fontsize=14)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)
ax.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.set_palette("Set2")
fig, ax = plt.subplots(figsize=(10, 6))
months = wanliu_month.index
ax.plot(months, wanliu_month['PM2.5']['mean'], label='PM2.5 Mean', marker='o', linewidth=2)
ax.plot(months, wanliu_month['PM2.5']['max'], label='PM2.5 Max', marker='x', linewidth=2)
ax.plot(months, wanliu_month['PM10']['mean'], label='PM10 Mean', marker='o', linewidth=2)
ax.plot(months, wanliu_month['PM10']['max'], label='PM10 Max', marker='x', linewidth=2)
ax.set_title('wanliu Monthly PM2.5 and PM10 Levels', fontsize=18, weight='bold')
ax.set_xlabel('Month', fontsize=14)
ax.set_ylabel('Concentration (µg/m³)', fontsize=14)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)
ax.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.set_palette("Set2")
fig, ax = plt.subplots(figsize=(10, 6))
year = wanshouxigong_year.index
ax.plot(year, wanshouxigong_year['PM2.5']['mean'], label='PM2.5 Mean', marker='o', linewidth=2)
ax.plot(year, wanshouxigong_year['PM2.5']['max'], label='PM2.5 Max', marker='x', linewidth=2)
ax.plot(year, wanshouxigong_year['PM10']['mean'], label='PM10 Mean', marker='o', linewidth=2)
ax.plot(year, wanshouxigong_year['PM10']['max'], label='PM10 Max', marker='x', linewidth=2)
ax.set_title('wanshouxigong Yearly PM2.5 and PM10 Levels', fontsize=18, weight='bold')
ax.set_xlabel('Year', fontsize=14)
ax.set_ylabel('Concentration (µg/m³)', fontsize=14)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)
ax.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.set_palette("Set2")
fig, ax = plt.subplots(figsize=(10, 6))
months = wanshouxigong_month.index
ax.plot(months, wanshouxigong_month['PM2.5']['mean'], label='PM2.5 Mean', marker='o', linewidth=2)
ax.plot(months, wanshouxigong_month['PM2.5']['max'], label='PM2.5 Max', marker='x', linewidth=2)
ax.plot(months, wanshouxigong_month['PM10']['mean'], label='PM10 Mean', marker='o', linewidth=2)
ax.plot(months, wanshouxigong_month['PM10']['max'], label='PM10 Max', marker='x', linewidth=2)
ax.set_title('wanshouxigong Monthly PM2.5 and PM10 Levels', fontsize=18, weight='bold')
ax.set_xlabel('Month', fontsize=14)
ax.set_ylabel('Concentration (µg/m³)', fontsize=14)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)
ax.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Pertanyaan 2: Apakah Curah hujan memiliki hubungan dengan polusi PM10 dan PM2.5?

# %%
mean_per_month = all_month[['PM10', 'PM2.5', 'RAIN']].groupby(all_month.index).mean()
plt.figure(figsize=(10, 6))
plt.plot(mean_per_month.index, mean_per_month['PM10'], label='Mean PM10')
plt.plot(mean_per_month.index, mean_per_month['PM2.5'], label='Mean PM2.5')
plt.plot(mean_per_month.index, mean_per_month['RAIN'], label='Mean Rain')
plt.title('Mean PM10, PM2.5, and Rain Per Month')
plt.xlabel('Month')
plt.ylabel('Mean Value')
plt.xticks(mean_per_month.index)
plt.legend()
plt.show()

# %% [markdown]
# **Insight:**
# - Grafik PM10 dan PM2.5 cenderung bergerak ke arah yang sama namun kadang tidak juga
# - Polusi udara cenderung turun saat curah hujan naik, dapat dilihat pada bulan 6 hingga 9

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Polusi PM10 dan PM2.5 saling berhubungan, dapat dilihat dari grafik bahwa saat salah satu meningkat konsentrasi nya, maka yang lain mengikuti, ini menandakan PM10 dan PM2.5 saling berhubungan atau berkorelasi
# - Konsentrasi PM10 daan PM2.5 cenderung turun saat curah hujan naik, dan naik saat curah hujan berada di 0, ini menandakan dengan turunnya hujan akan mengurangi polusi di udara
